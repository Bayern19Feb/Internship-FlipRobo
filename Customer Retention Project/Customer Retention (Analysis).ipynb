# %% [markdown]
# ## Problem Statement:
#
# - Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store, it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty.
#
#
# - A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention.
#
#
# - Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit.
#
#
# - The research furthermore investigated the factors that influence the online customers repeat purchase intention.
#
#
# - The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively.

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Code to display rows and column borders

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %% [markdown]
# ### Code to display all the rows in the dataset

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Code to display all the rows in the dataset

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Code to hide warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing dataset

# %%
df = pd.read_excel("customer_retention_dataset.xlsx")

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# ### Column info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# ### Data Overview:
#
# - A total of 269 entries in the data set
#
#
# - 71 column names
#
#
# - Data types include Int and Objects
#
#
# - Some null values in the data set

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# ### Problem Type
#
# - The goal is to perform thorough data analysis in order to find hidden information and patterns from the data.
#
#
#
# - The management will then use this analysis and accordingly manipulate the strategy of their companies to concentrate and focus on areas of regaining more customers and providing high-quality services for customers to maintain their loyalty.

# %% [markdown]
# ### Lets check for duplicate values

# %%
df.duplicated().sum()
# Out:
# 166

# %%
# We need to remove duplicated values

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# ### Lets Rename the column names

# %%
df = df.rename(columns={df.columns[0]:"Gender",
                        df.columns[1]:"Age",
                       df.columns[2]:"City",
                       df.columns[3]:"Pin", 
                       df.columns[4]:"SHLSO", 
                       df.columns[5]:"NOPPY",
                       df.columns[6]:"IA",
                       df.columns[7]:"Device_Usage",
                       df.columns[8]:"Screen_size",
                       df.columns[9]:"OS",
                       df.columns[10]:"Browser",
                       df.columns[11]:"Channel",df.columns[12]:"MRORS",df.columns[13]:"Duration(mins)",
                       df.columns[14]:"Payment_pref",df.columns[15]:"FOIA",df.columns[16]:"RFA",
                       df.columns[17]:"WCR",df.columns[18]:"IPCH",df.columns[19]:"IASAP",
                       df.columns[20]:"RIAP",df.columns[21]:"EWN",df.columns[22]:"Speed(L&A)",
                       df.columns[23]:"UFI",df.columns[24]:"CPM",df.columns[25]:"TOSCT",
                       df.columns[26]:"Cust_Support_Empathy",df.columns[27]:"Privacy_Guarantee",df.columns[28]:"RCC",
                       df.columns[29]:"Discounts",df.columns[30]:"EOS",
                       df.columns[31]:"C&F",df.columns[32]:"R&R",df.columns[33]:"GALP",
                       df.columns[34]:"DQI",df.columns[35]:"SOA",df.columns[36]:"OSBUS",
                       df.columns[37]:"NSNT",df.columns[38]:"Wide_Variety",df.columns[39]:"Complete_prod_info",
                       df.columns[40]:"MS",df.columns[41]:"CPR",df.columns[42]:"Adventure",
                       df.columns[43]:"Social_status",df.columns[44]:"Gratification",df.columns[45]:"SFR",
                       df.columns[46]:"VFM",df.columns[47]:"C_E_R",df.columns[48]:"ETU",
                       df.columns[49]:"Best_Homepage",df.columns[50]:"VOP",df.columns[51]:"RDOI",
                       df.columns[52]:"Loading_speed",df.columns[53]:"ROA",df.columns[54]:"Purchase_speed",
                       df.columns[55]:"Payment_options",df.columns[56]:"Delivery_speed",df.columns[57]:"Cust_privacy",
                       df.columns[58]:"COFI",df.columns[59]:"Trustworthiness",df.columns[60]:"Online_Ass",
                       df.columns[61]:"Login(TD)",df.columns[62]:"LTDG&P",df.columns[63]:"Late_declaration",
                       df.columns[64]:"Page_load_time",df.columns[65]:"LTM_paymet_modes",df.columns[66]:"Delayed_delivery",
                       df.columns[67]:"CID",df.columns[68]:"FDP",df.columns[69]:"Website_eff",
                       df.columns[70]:"Friend_Suggest"})

# %%
df.head()
# Out:
#    Gender          Age           City     Pin          SHLSO  \
# 0    Male  31-40 years          Delhi  110009  Above 4 years
# 1  Female  21-30 years          Delhi  110030  Above 4 years
# 2  Female  21-30 years  Greater Noida  201308      3-4 years
# 3    Male  21-30 years        Karnal   132001      3-4 years
# 4  Female  21-30 years     Bangalore   530068      2-3 years
#
#                 NOPPY               IA Device_Usage Screen_size  \
# 0         31-40 times          Dial-up      Desktop      Others
# 1  41 times and above            Wi-Fi   Smartphone  4.7 inches
# 2  41 times and above  Mobile Internet   Smartphone  5.5 inches
# 3  Less than 10 times  Mobile Internet   Smartphone  5.5 inches
# 4         11-20 times            Wi-Fi   Smartphone  4.7 inches
#
#                       OS        Browser            Channel            MRORS  \
# 0  Window/windows Mobile  Google chrome      Search Engine    Search Engine
# ...

# %% [markdown]
# ### Column Description
#
# - 0 Gender of respondent : Gender
#
# - 1 How old are you? : Age
#
# - 2 Which city do you shop online from? : City
#
# - 3 What is the Pin Code of where you shop online from? : Pin
#
# - 4 Since How Long You are Shopping Online ?: SHLSO
#
# - 5 How many times you have made an online purchase in the past 1 year? : NOPPY
#
# - 6 How do you access the internet while shopping on-line? : IA
#
# - 7 Which device do you use to access the online shopping? : Device_Usage
#
# - 8 What is the screen size of your mobile device?\t\t\t\t\t\t : Screen_size
#
# - 9 What is the operating system (OS) of your device?\t\t\t\t : OS
#
# - 10 What browser do you run on your device to access the website?\t\t\t: Browser
#
# - 11 Which channel did you follow to arrive at your favorite online store for the first time?: Channel
#
# - 12 After first visit, how do you reach the online retail store?\t\t\t\t : MRORS
#
# - 13 How much time do you explore the e- retail store before making a purchase decision? : Duration(mins)
#
# - 14 What is your preferred payment Option?\t\t\t\t\t : Payment_pref
#
# - 15 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t : FOIA
#
# - 16 Why did you abandon the “Bag”, “Shopping Cart”? : RFA
#
# - 17 The content on the website must be easy to read and understand : WCR
#
# - 18 Information on similar product to the one highlighted is important for product comparison : IPCH
#
# - 19 Complete information on listed seller and product being offered is important for purchase decision. : IASAP
#
# - 20 All relevant information on listed products must be stated clearly : RIAP
#
# - 21 Ease of navigation in website : EWN
#
# - 22 Loading and processing speed : Speed(L&A)
#
# - 23 User friendly Interface of the website : UFI
#
# - 24 Convenient Payment methods : CPM
#
# - 25 Trust that the online retail store will fulfill its part of the transaction at the stipulated time : TOSCT
#
# - 26 Empathy (readiness to assist with queries) towards the customers : Cust_Support_Empathy
#
# - 27 Being able to guarantee the privacy of the customer : Privacy_Guarantee
#
# - 28 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.) : RCC
#
# - 29 Online shopping gives monetary benefit and discounts : Discounts
#
# - 30 Enjoyment is derived from shopping online : EOS
#
# - 31 Shopping online is convenient and flexible : C&F
#
# - 32 Return and replacement policy of the e-tailer is important for purchase decision : R&R
#
# - 33 Gaining access to loyalty programs is a benefit of shopping online : GALP
#
# - 34 Displaying quality Information on the website improves satisfaction of customers : DQI
#
# - 35 User derive satisfaction while shopping on a good quality website or application : SOA
#
# - 36 Net Benefit derived from shopping online can lead to users satisfaction : OSBUS
#
# - 37 User satisfaction cannot exist without trust : NSNT
#
# - 38 Offering a wide variety of listed product in several category : Wide_Variety
#
# - 39 Provision of complete and relevant product information : Complete_prod_info
#
# - 40 Monetary savings : MS
#
# - 41 The Convenience of patronizing the online retailer : CPR
#
# - 42 Shopping on the website gives you the sense of adventure : Adventure
#
# - 43 Shopping on your preferred e-tailer enhances your social status : Social_status
#
# - 44 You feel gratification shopping on your favorite e-tailer : Gratification
#
# - 45 Shopping on the website helps you fulfill certain roles : SFR
#
# - 46 Getting value for money spent : VFM
#
# - 47 From the following, tick any (or all) of the online retailers you have shopped from : C_E_R
#
# - 48 Easy to use website or application : ETU
#
# - 49 Visual appealing web-page layout : Best_Homepage
#
# - 50 Wild variety of product on offer : VOP
#
# - 51 Complete, relevant description information of products : RDOI
#
# - 52 Fast loading website speed of website and application : Loading_speed
#
# - 53 Reliability of the website or application : ROA
#
# - 54 Quickness to complete purchase : Purchase_speed
#
# - 55 Availability of several payment options : Payment_options
#
# - 56 Speedy order delivery":"Delivery_speed"
#
# - 57 Privacy of customers’ information : Cust_privacy
#
# - 58 Security of customer financial information : COFI
#
# - 59 Perceived Trustworthiness : Trustworthiness
#
# - 60 Presence of online assistance through multi-channel : Online_Ass
#
# - 61 Longer time to get logged in (promotion, sales period): Login(TD)
#
# - 62 Longer time in displaying graphics and photos (promotion, sales period): LTDG&P
#
# - 63 Late declaration of price (promotion, sales period) : Late_declaration
#
# - 64 Longer page loading time (promotion, sales period) : Page_load_time
#
# - 65 Limited mode of payment on most products (promotion, sales period) : LTM_paymet_modes
#
# - 66 Longer delivery period : Delayed_delivery
#
# - 67 Change in website/Application design":CID
#
# - 68 Frequent disruption when moving from one page to another: FDP
#
# - 69 Website is as efficient as before: Website_eff
#
# - 70 Which of the Indian online retailer would you recommend to a friend? : Friend_Suggest

# %%
# check number and percentage of missing values in each column

# Creating a function name missing values table
def missing_values_table(data):
        
        # Total missing values
        mis_val = data.isnull().sum() 
        
        # Percentage of missing values
        mis_val_percent = 100 * data.isnull().sum() / len(data) 
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1) 
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'}) 
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(data.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
# Calling the function
missing_values_table(df)
# Out:
# Your selected dataframe has 71 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
# No missing values in data

# %%
df.isnull().sum()
# Out:
# Gender                  0
# Age                     0
# City                    0
# Pin                     0
# SHLSO                   0
# NOPPY                   0
# IA                      0
# Device_Usage            0
# Screen_size             0
# OS                      0
# Browser                 0
# Channel                 0
# MRORS                   0
# Duration(mins)          0
# Payment_pref            0
# FOIA                    0
# RFA                     0
# WCR                     0
# IPCH                    0
# IASAP                   0
# RIAP                    0
# EWN                     0
# Speed(L&A)              0
# UFI                     0
# CPM                     0
# TOSCT                   0
# Cust_Support_Empathy    0
# Privacy_Guarantee       0
# RCC                     0
# Discounts               0
# EOS                     0
# C&F                     0
# R&R                     0
# GALP                    0
# DQI                     0
# ...

# %% [markdown]
# ## EDA Exploratory Data Analysis

# %%
df.head()
# Out:
#    Gender          Age           City     Pin          SHLSO  \
# 0    Male  31-40 years          Delhi  110009  Above 4 years
# 1  Female  21-30 years          Delhi  110030  Above 4 years
# 2  Female  21-30 years  Greater Noida  201308      3-4 years
# 3    Male  21-30 years        Karnal   132001      3-4 years
# 4  Female  21-30 years     Bangalore   530068      2-3 years
#
#                 NOPPY               IA Device_Usage Screen_size  \
# 0         31-40 times          Dial-up      Desktop      Others
# 1  41 times and above            Wi-Fi   Smartphone  4.7 inches
# 2  41 times and above  Mobile Internet   Smartphone  5.5 inches
# 3  Less than 10 times  Mobile Internet   Smartphone  5.5 inches
# 4         11-20 times            Wi-Fi   Smartphone  4.7 inches
#
#                       OS        Browser            Channel            MRORS  \
# 0  Window/windows Mobile  Google chrome      Search Engine    Search Engine
# ...

# %%
# Setting the style
sns.set(style='darkgrid')

# %%
# using Seaborn's count plot
plt.figure(figsize=(10,8))
sns.countplot(x="Gender",data=df)
df["Gender"].value_counts()
plt.title("Gender of respondent",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gender of respondent')

# %% [markdown]
# The number of female respondents is higher than male respondents.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Age",data=df)
plt.title("How old are you?(Age Range)",fontsize=15)
df["Age"].value_counts()
# Out:
# 21-30 years           32
# 31-40 years           30
# 41-50 yaers           29
# Less than 20 years     6
# 51 years and above     6
# Name: Age, dtype: int64

# %% [markdown]
# Most of the customers are within the Age range (21 - 50) years.
#
# Less customers from age group below 20 years and above 51 years

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="City",data=df)
plt.title("Which city do you shop online from?",fontsize=15)
df["City"].value_counts()
# Out:
# Delhi            22
# Noida            17
# Greater Noida    17
# Bangalore        17
# Karnal           11
# Ghaziabad         5
# Merrut            5
# Solan             4
# Gurgaon           3
# Bulandshahr       1
# Moradabad         1
# Name: City, dtype: int64

# %% [markdown]
# Delhi has the highest number of customers who are involved in online shopping (Important customers for the e-commerce company) followed by Greater Noida, Bangalore, and Noida.
#
#
#
# Moradabad, Bulandshahr have very few customers (the Ecom companies should investigate and find out the reasons for customers being less in those areas) and try to enhance sales in those areas.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="SHLSO",data=df)
plt.title("Since How Long You are Shopping Online?",fontsize=15)
df["SHLSO"].value_counts()
# Out:
# Above 4 years       39
# 2-3 years           23
# Less than 1 year    18
# 3-4 years           16
# 1-2 years            7
# Name: SHLSO, dtype: int64

# %% [markdown]
# Most of the regular customers have been shopping for more than 4 years(Important customers, loyal customers)
#
# Need to provide best services to customers who have recently been shopping for less than 1 year (better the service more the loyalty)

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="NOPPY",data=df,palette="Dark2_r")
plt.title("How many times you have made an online purchase in the past 1 year?",fontsize=15)
df["NOPPY"].value_counts()
# Out:
# Less than 10 times    39
# 31-40 times           24
# 41 times and above    22
# 11-20 times           12
# 21-30 times            4
# 42 times and above     2
# Name: NOPPY, dtype: int64

# %% [markdown]
# Less than 10 times is the highest count for the customers who have purchased something online in the past 1 year(maybe average customers).
#
#
# 41 times and 42 times and above are important customers to the e-commerce company (Customers who have a high engagement rate in online purchases)
#
# Mostly an average customer is buying ~ 10 items yearly

# %%
df["IA"] = df["IA"].replace({"Mobile Internet":"Mobile internet"})

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="IA",data=df)
plt.title("How do you access the internet while shopping on-line?",fontsize=15)
df["IA"].value_counts()
# Out:
# Mobile internet    81
# Wi-Fi              21
# Dial-up             1
# Name: IA, dtype: int64

# %% [markdown]
# Most of the customers are using mobile data(Internet) while shopping online

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Device_Usage",data=df,palette="Dark2")
plt.title("Which device do you use to access the online shopping?",fontsize=15)
df["Device_Usage"].value_counts()
# Out:
# Smartphone    52
# Laptop        32
# Desktop       13
# Tablet         6
# Name: Device_Usage, dtype: int64

# %% [markdown]
# Laptops and smartphones are the most used devices for online shopping.
#
#
# Tablet's are the least used devices.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="OS",data=df)
plt.title("What is the operating system (OS) of your device?",fontsize=15)
df["OS"].value_counts()
# Out:
# Window/windows Mobile    46
# Android                  30
# IOS/Mac                  27
# Name: OS, dtype: int64

# %% [markdown]
# Most of the customers are using Window's operating system on their devices.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Browser",data=df,palette="CMRmap_r")
plt.title("What browser do you run on your device to access the website?",fontsize=15)
df["Browser"].value_counts()
# Out:
# Google chrome      80
# Safari             19
# Opera               2
# Mozilla Firefox     2
# Name: Browser, dtype: int64

# %% [markdown]
# Most of the customers prefer using Google Chrome as their default browser for online shopping.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Channel",data=df,palette="BuGn_r")
plt.title("Which channel did you follow to arrive at your favorite online store for the first time?",fontsize=15)
df["Channel"].value_counts()
# Out:
# Search Engine        86
# Content Marketing    10
# Display Adverts       7
# Name: Channel, dtype: int64

# %% [markdown]
# Most individual's used Search engines as a channel to arrive at their favourite online store.
#
# The least number of customers arrived at their favourite online store via Display Adverts.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="MRORS",data=df,palette="Blues_r")
plt.title("After first visit, how do you reach the online retail store?",fontsize=15)
df["MRORS"].value_counts()
# Out:
# Via application    34
# Search Engine      33
# Direct URL         26
# E-mail              8
# Social Media        2
# Name: MRORS, dtype: int64

# %% [markdown]
# After the first visit, most of the individuals prefer to use the Application (mobile app) of the online store or used the Search Engine channel to reach the online store.
#
#
# Social media had very less influence (Companies can work on their social media marketing).

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Duration(mins)",data=df,palette="Blues")
plt.title("How much time do you explore the e- retail store before making a purchase decision?",fontsize=15)
df["Duration(mins)"].value_counts()
# Out:
# more than 15 mins    48
# 6-10 mins            31
# 11-15 mins           15
# 1-5 mins              5
# Less than 1 min       4
# Name: Duration(mins), dtype: int64

# %% [markdown]
# On average an individual spent more than 15 minutes on the website before making a purchase decision.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Payment_pref",data=df,palette="Accent_r")
plt.title("What is your preferred payment Option?",fontsize=15)
df["Payment_pref"].value_counts()
# Out:
# Credit/Debit cards                    59
# Cash on delivery (CoD)                25
# E-wallets (Paytm, Freecharge etc.)    19
# Name: Payment_pref, dtype: int64

# %% [markdown]
# Most of the customers preferred a Credit/Debit cards as their payment method.
#
# Very few customers preferred E-wallets (Paytm, Freecharge, etc.)

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="FOIA",data=df,palette="Accent")
plt.title("How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?",fontsize=15)
df["FOIA"].value_counts()
# Out:
# Sometimes          64
# Never              17
# Frequently         16
# Very frequently     6
# Name: FOIA, dtype: int64

# %% [markdown]
# When it comes to adding an item to the cart but not buying it, most of the customers tend to do it "sometimes" (Due to various personal reasons)

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="RFA",data=df,palette="Dark2_r")
plt.title("Why did you abandon the “Bag”, “Shopping Cart”?",fontsize=15)
df["RFA"].value_counts()
# Out:
# Better alternative offer        49
# Promo code not applicable       21
# Change in price                 15
# Lack of trust                   13
# No preferred mode of payment     5
# Name: RFA, dtype: int64

# %% [markdown]
# The most frequent reason for customers not buying the added item in the cart is having a better alternative offer on the same product.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="WCR",data=df,palette="OrRd_r")
plt.title("The content on the website must be easy to read and understand?",fontsize=15)
df["WCR"].value_counts()
# Out:
# Strongly agree (5)       60
# Agree (4)                33
# Strongly disagree (1)     8
# Indifferent (3)           2
# Name: WCR, dtype: int64

# %% [markdown]
# It is very important that the content on the website must be easy to read and understand.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="IPCH",data=df,palette="Purples_r")
plt.title("Information on similar product to the one highlighted is important for product comparison?",fontsize=15)
df["IPCH"].value_counts()
# Out:
# Strongly agree (5)    40
# Agree (4)             35
# Indifferent (3)       20
# Dis-agree (2)          8
# Name: IPCH, dtype: int64

# %% [markdown]
# Product comparison is a must and is an important factor as the customer will always try to buy what suits best for his needs. Suggesting similar products should be imminent.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="IASAP",data=df,palette="Dark2_r")
plt.title("Complete information on listed seller and product being offered is important for purchase decision?",fontsize=15)
df["IASAP"].value_counts()
# Out:
# Agree (4)                38
# Strongly agree (5)       30
# Indifferent (3)          24
# Dis-agree (2)             8
# Strongly disagree (1)     3
# Name: IASAP, dtype: int64

# %% [markdown]
# Most of the customers agree with providing complete information on the listed sellers and products being offered as it gives them extra assurance in case something went wrong with the product.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="RIAP",data=df,palette="Set2_r")
plt.title("All relevant information on listed products must be stated clearly?",fontsize=15)
df["RIAP"].value_counts()
# Out:
# Agree (4)                54
# Strongly agree (5)       37
# Strongly disagree (1)     8
# Dis-agree (2)             4
# Name: RIAP, dtype: int64

# %% [markdown]
# It is very important that the product information(specifications) should be accurate and authentic.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="EWN",data=df,palette="Spectral_r")
plt.title("Ease of navigation in website?",fontsize=15)
df["EWN"].value_counts()
# Out:
# Strongly agree (5)       51
# Agree (4)                42
# Strongly disagree (1)     8
# Dis-agree (2)             2
# Name: EWN, dtype: int64

# %% [markdown]
# The websites for online stores must be simple to navigate.New users must not have any difficulty while shopping.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Speed(L&A)",data=df,palette="gist_earth_r")
plt.title("Loading and processing speed?",fontsize=15)
df["Speed(L&A)"].value_counts()
# Out:
# Strongly agree (5)       45
# Agree (4)                41
# Dis-agree (2)             8
# Strongly disagree (1)     5
# Indifferent (3)           4
# Name: Speed(L&A), dtype: int64

# %% [markdown]
# It is very important for customers that the loading speed for their favorite online store should be adequate.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="UFI",data=df,palette="gist_rainbow_r")
plt.title("User friendly Interface of the website",fontsize=15)
df["UFI"].value_counts()
# Out:
# Strongly agree (5)       72
# Agree (4)                16
# Strongly disagree (1)     8
# Dis-agree (2)             5
# Indifferent (3)           2
# Name: UFI, dtype: int64

# %% [markdown]
# From the user's perspective, an user-friendly UI(user interface) is very important.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="CPM",data=df,palette="gist_rainbow_r")
plt.title("Convenient Payment methods?",fontsize=15)
df["CPM"].value_counts()
# Out:
# Strongly agree (5)    60
# Agree (4)             30
# Dis-agree (2)         13
# Name: CPM, dtype: int64

# %% [markdown]
# It is important to have a lot of payment options that are easy to use.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="TOSCT",data=df,palette="gist_rainbow")
plt.title("Trust that the online retail store will fulfill its part of the transaction at the stipulated time?",fontsize=15)
df["TOSCT"].value_counts()
# Out:
# Strongly agree (5)    52
# Agree (4)             34
# Disagree (2)          13
# indifferent  (3)       4
# Name: TOSCT, dtype: int64

# %% [markdown]
# Probably the most important factor for users in terms of payment. The payment should be completed in a time span as it will increase the trustworthiness of customers.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Cust_Support_Empathy",data=df,palette="gist_rainbow")
plt.title("Empathy (readiness to assist with queries) towards the customers?",fontsize=15)
df["Cust_Support_Empathy"].value_counts()
# Out:
# Strongly agree (5)       75
# Agree (4)                16
# Strongly disagree (1)     8
# indifferent (3)           4
# Name: Cust_Support_Empathy, dtype: int64

# %% [markdown]
# Customer support is a crucial factor to improve customer loyalty and trust.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Privacy_Guarantee",data=df,palette="gist_rainbow")
plt.title("Being able to guarantee the privacy of the customer?",fontsize=15)
df["Privacy_Guarantee"].value_counts()
# Out:
# Strongly agree (5)    69
# Agree (4)             24
# indifferent (3)       10
# Name: Privacy_Guarantee, dtype: int64

# %% [markdown]
# Customer privacy is a crucial factor. Customers should feel safe while shopping.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="RCC",data=df,palette="gist_rainbow")
plt.title("Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)?",fontsize=15)
df["RCC"].value_counts()
# Out:
# Strongly agree (5)       59
# Agree (4)                36
# indifferent (3)           5
# Strongly disagree (1)     3
# Name: RCC, dtype: int64

# %% [markdown]
# The website should be responsive as users will use different devices to access the website. Having various channels for handling user queries is crucial.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Discounts",data=df,palette="gist_rainbow")
plt.title("Online shopping gives monetary benefit and discounts?",fontsize=15)
df["Discounts"].value_counts()
# Out:
# Strongly agree (5)       41
# Agree (4)                33
# indifferent (3)          16
# Strongly disagree (1)     8
# Dis-agree (2)             5
# Name: Discounts, dtype: int64

# %% [markdown]
# Monetary benefit and Discounts are influential to attract more customers in buying products online.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="EOS",data=df,palette="gist_rainbow")
plt.title("Enjoyment is derived from shopping online?",fontsize=15)
df["EOS"].value_counts()
# Out:
# Strongly agree (5)       34
# indifferent (3)          27
# Agree (4)                23
# Strongly disagree (1)    13
# Dis-agree (2)             6
# Name: EOS, dtype: int64

# %% [markdown]
# Most of the users enjoy the experience of online shopping.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="C&F",data=df,palette="gist_rainbow")
plt.title("Shopping online is convenient and flexible?",fontsize=15)
df["C&F"].value_counts()
# Out:
# Strongly agree (5)    56
# Agree (4)             29
# indifferent (3)       13
# Dis-agree (2)          5
# Name: C&F, dtype: int64

# %% [markdown]
# The highest number of customers believe that online shopping is convenient and flexible.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="R&R",data=df,palette="Dark2_r")
plt.title("Return and replacement policy of the e-tailer is important for purchase decision?",fontsize=15)
df["R&R"].value_counts()
# Out:
# Strongly agree (5)    76
# Agree (4)             20
# Dis-agree (2)          7
# Name: R&R, dtype: int64

# %% [markdown]
# In case the delivered product turns out to be faulty than in such cases return and replacement policy is very crucial.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="GALP",data=df,palette="Dark2_r")
plt.title("Gaining access to loyalty programs is a benefit of shopping online?",fontsize=15)
df["GALP"].value_counts()
# Out:
# Strongly agree (5)       44
# Agree (4)                24
# indifferent (3)          22
# Dis-agree (2)             8
# Strongly disagree (1)     5
# Name: GALP, dtype: int64

# %% [markdown]
# This service can enhance the experience for loyal customers.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="DQI",data=df,palette="Dark2_r")
plt.title("Displaying quality Information on the website improves satisfaction of customers?",fontsize=15)
df["DQI"].value_counts()
# Out:
# Strongly agree (5)    49
# Agree (4)             31
# indifferent (3)       23
# Name: DQI, dtype: int64

# %% [markdown]
# It is important that the website displays quality information to improve the user experience.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="SOA",data=df,palette="Dark2_r")
plt.title("User derive satisfaction while shopping on a good quality website or application?",fontsize=15)
df["SOA"].value_counts()
# Out:
# Strongly agree (5)    66
# Agree (4)             35
# Dis-agree (2)          2
# Name: SOA, dtype: int64

# %% [markdown]
# The website should be attractive, easy to navigate, and should have good customer support for users to be satisfied.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="OSBUS",data=df,palette="Dark2_r")
plt.title("Net Benefit derived from shopping online can lead to users satisfaction?",fontsize=15)
df["OSBUS"].value_counts()
# Out:
# Strongly agree (5)    61
# Agree (4)             22
# indifferent (3)       15
# Dis-agree (2)          5
# Name: OSBUS, dtype: int64

# %% [markdown]
# Customers agree with the fact that Better the benefits more the satisfaction for customers

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Wide_Variety",data=df,palette="Dark2_r")
plt.title("Offering a wide variety of listed product in several category?",fontsize=15)
df["Wide_Variety"].value_counts()
# Out:
# Strongly agree (5)    42
# Agree (4)             39
# indifferent (3)       20
# Dis-agree (2)          2
# Name: Wide_Variety, dtype: int64

# %% [markdown]
# When it comes to shopping has a lot of alternatives for products is crucial as it helps the customer to choose the best option.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Adventure",data=df,palette="Dark2_r")
plt.title("Shopping on the website gives you the sense of adventure?",fontsize=15)
df["Adventure"].value_counts()
# Out:
# Agree (4)                42
# indifferent (3)          24
# Strongly agree (5)       20
# Dis-agree (2)            15
# Strongly disagree (1)     2
# Name: Adventure, dtype: int64

# %% [markdown]
# Most of the customers think that shopping online gives them a sense of adventure.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Social_status",data=df,palette="Dark2_r")
plt.title("Shopping on your preferred e-tailer enhances your social status?",fontsize=15)
df["Social_status"].value_counts()
# Out:
# indifferent (3)          39
# Agree (4)                21
# Strongly agree (5)       17
# Strongly disagree (1)    16
# Dis-agree (2)            10
# Name: Social_status, dtype: int64

# %% [markdown]
# According to most of the customers, there is no effect of online shopping on social status.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="VFM",data=df,palette="Dark2_r")
plt.title("Getting value for money spent?",fontsize=15)
df["VFM"].value_counts()
# Out:
# Agree (4)             57
# Strongly agree (5)    32
# indifferent (3)       14
# Name: VFM, dtype: int64

# %% [markdown]
# Most of the customers agree to the fact that in online shopping you get good value for your money.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="C_E_R",data=df,palette="Dark2_r")
plt.title("From the following, tick any (or all) of the online retailers you have shopped from?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["C_E_R"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16
# Amazon.in, Flipkart.com                                         12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                12
# Amazon.in, Flipkart.com, Snapdeal.com                            8
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Paytm.com                                             5
# Amazon.in                                                        4
# Amazon.in, Flipkart.com, Paytm.com                               2
# Name: C_E_R, dtype: int64

# %% [markdown]
# Most of the customers prefer Amazon. in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com for shopping.
#
# We can say that these are the top 5 best e-commerce companies in India.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="ETU",data=df,palette="Dark2_r")
plt.title("Easy to use website or application?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["ETU"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    28
# Amazon.in, Flipkart.com                                         18
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                10
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in                                                        8
# Amazon.in, Flipkart.com, Myntra.com                              6
# Paytm.com                                                        5
# Flipkart.com                                                     2
# Amazon.in, Paytm.com                                             2
# Name: ETU, dtype: int64

# %% [markdown]
# According to most of the customer's Amazon. in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com are easy-to-use websites for online shopping.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Best_Homepage",data=df,palette="Dark2_r")
plt.title("Visual appealing web-page layout?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["Best_Homepage"].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         33
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    16
# Amazon.in                                                       12
# Myntra.com                                                       8
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Myntra.com                                            6
# Flipkart.com                                                     5
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                 5
# Flipkart.com, Myntra.com                                         5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Name: Best_Homepage, dtype: int64

# %% [markdown]
# According to most of the customer's Amazon. in, Flipkart.com has the best home page in terms of design and user experience.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="VOP",data=df,palette="Dark2_r")
plt.title("Wild variety of product on offer?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["VOP"].value_counts()
# Out:
# Amazon.in, Flipkart.com                              50
# Amazon.in                                            13
# Myntra.com                                            8
# Amazon.in, Myntra.com                                 8
# Flipkart.com, Myntra.com                              6
# Amazon.in, Flipkart.com, Paytm.com                    6
# Flipkart.com                                          5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     5
# Paytm.com                                             2
# Name: VOP, dtype: int64

# %% [markdown]
# Customers vote for Amazon. in and Flipkart.com as the best e-commerce sites when it comes to the variety of products.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="RDOI",data=df,palette="Dark2_r")
plt.title("Complete, relevant description information of products?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["RDOI"].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         39
# Amazon.in                                                       12
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     8
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Flipkart.com, Myntra.com                              6
# Flipkart.com, Snapdeal.com                                       5
# Snapdeal.com                                                     5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Snapdeal.com                            2
# Flipkart.com                                                     2
# Name: RDOI, dtype: int64

# %% [markdown]
# The highest number of customers vote for Amazon.in and Flipkart.com for displaying Complete, relevant description information of products which is important for the customer.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Loading_speed",data=df,palette="Dark2_r")
plt.title("Fast loading website speed of website and application?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Loading_speed"].value_counts()
# Out:
# Amazon.in, Paytm.com                                            19
# Amazon.in                                                       18
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    11
# Amazon.in, Flipkart.com, Snapdeal.com                           11
# Amazon.in, Flipkart.com                                         11
# Amazon.in, Flipkart.com, Myntra.com                             11
# Amazon.in, Flipkart.com, Paytm.com                              10
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Snapdeal.com                                                     5
# Flipkart.com                                                     2
# Name: Loading_speed, dtype: int64

# %% [markdown]
# When it comes to loading speed Amazon. in, Paytm.com we voted as the fastest loading websites.
#
# According to this survey, flipkart.com has a slower loading speed.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="ROA",data=df,palette="Dark2_r")
plt.title("Reliability of the website or application?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["ROA"].value_counts()
# Out:
# Amazon.in                                            20
# Amazon.in, Flipkart.com                              18
# Amazon.in, Flipkart.com, Paytm.com                   16
# Amazon.in, Paytm.com, Myntra.com                     16
# Amazon.in, Flipkart.com, Snapdeal.com                 7
# Myntra.com                                            6
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com      6
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     5
# Paytm.com                                             5
# Flipkart.com                                          4
# Name: ROA, dtype: int64

# %% [markdown]
# According to the customer votes, Amazon. in is the most reliable eCommerce website as compared to other online shopping websites.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Purchase_speed",data=df,palette="Dark2_r")
plt.title("Quickness to complete purchase?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Purchase_speed"].value_counts()
# Out:
# Amazon.com                                                   22
# Amazon.com, Flipkart.com, Paytm.com                          21
# Amazon.com, Flipkart.com                                     13
# Amazon.com, Flipkart.com, Myntra.com                         11
# Paytm.com                                                    11
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal     8
# Amazon.com, Paytm.com, Myntra.com                             8
# Flipkart.com, Myntra.com, Snapdeal                            5
# Flipkart.com                                                  4
# Name: Purchase_speed, dtype: int64

# %% [markdown]
# According to a customer survey Amazon.in has the fastest purchase complete rate as compared to other websites.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Payment_options",data=df,palette="Dark2_r")
plt.title("Availability of several payment options?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Payment_options"].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         25
# Amazon.in, Flipkart.com, Myntra.com                             17
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    17
# Patym.com, Myntra.com                                            8
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                6
# Amazon.in                                                        6
# Flipkart.com, Myntra.com, Snapdeal.com                           5
# Patym.com                                                        5
# Amazon.in, Patym.com                                             5
# Flipkart.com                                                     2
# Name: Payment_options, dtype: int64

# %% [markdown]
# Amazon. in, Flipkart.com has the most number of payment alternatives.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Delivery_speed",data=df,palette="Dark2_r")
plt.title("Speedy order delivery?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Delivery_speed"].value_counts()
# Out:
# Amazon.in                                 43
# Amazon.in, Flipkart.com                   30
# Amazon.in, Flipkart.com, Snapdeal.com     16
# Flipkart.com, Myntra.com, Snapdeal.com     5
# Amazon.in, Flipkart.com, Myntra.com        5
# Flipkart.com                               4
# Name: Delivery_speed, dtype: int64

# %% [markdown]
# Amazon.com has the fastest delivery speed as compared to other e-commerce stores.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Cust_privacy",data=df,palette="Dark2_r")
plt.title("Privacy of customers’ information?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Cust_privacy"].value_counts()
# Out:
# Amazon.in                                                       24
# Amazon.in, Flipkart.com                                         19
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    11
# Amazon.in, Flipkart.com, Myntra.com                             11
# Paytm.com                                                        8
# Amazon.in, Paytm.com                                             8
# Myntra.com                                                       6
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Paytm.com                               5
# Flipkart.com                                                     4
# Amazon.in, Flipkart.com, Snapdeal.com                            2
# Name: Cust_privacy, dtype: int64

# %% [markdown]
# When it comes to protecting the privacy of customers' information, Amazon.in is ranked as the best by users.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="COFI",data=df,palette="Dark2_r")
plt.title("Security of customer financial information?",fontsize=15)
df["COFI"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    16
# Amazon.in                                                       16
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Snapdeal.com                           11
# Amazon.in, Flipkart.com                                         10
# Paytm.com                                                        8
# Amazon.in, Paytm.com, Myntra.com                                 8
# Myntra.com                                                       6
# Amazon.in, Snapdeal.com                                          6
# Amazon.in, Flipkart.com, Paytm.com                               5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Name: COFI, dtype: int64

# %% [markdown]
# Amazon.in is leading when it comes to Security for customer's financial information security.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Trustworthiness",data=df,palette="Dark2_r")
plt.title("Perceived Trustworthiness?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Trustworthiness"].value_counts()
# Out:
# Amazon.in                                                       25
# Amazon.in, Myntra.com                                           16
# Amazon.in, Flipkart.com, Snapdeal.com                           16
# Amazon.in, Flipkart.com                                         12
# Flipkart.com                                                     9
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                8
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     6
# Myntra.com                                                       6
# Amazon.in, Flipkart.com, Paytm.com                               5
# Name: Trustworthiness, dtype: int64

# %% [markdown]
# Amazon.in turns out to be the most trusted e-commerce website.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Online_Ass",data=df,palette="Dark2_r")
plt.title("Presence of online assistance through multi-channel?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Online_Ass"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    24
# Amazon.in                                        21
# Amazon.in, Flipkart.com                          15
# Amazon.in, Snapdeal                               8
# Myntra.com                                        8
# Amazon.in, Myntra.com                             8
# Amazon.in, Flipkart.com, Paytm.com                6
# Amazon.in, Flipkart.com, Myntra.com               6
# Paytm.com                                         5
# Flipkart.com                                      2
# Name: Online_Ass, dtype: int64

# %% [markdown]
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal have the highest customer votes for the Presence of online assistance through multi-channel

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Login(TD)",data=df,palette="Dark2_r")
plt.title("Longer time to get logged in (promotion, sales period)?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["Login(TD)"].value_counts()
# Out:
# Amazon.in                                18
# Amazon.in, Flipkart.com                  16
# Paytm.com                                14
# Myntra.com                               13
# Snapdeal.com                             11
# Amazon.in, Flipkart.com, Snapdeal.com    10
# Flipkart.com, Paytm.com                   8
# Flipkart.com, Paytm.com, Snapdeal.com     6
# Amazon.in, Paytm.com                      5
# Flipkart.com                              2
# Name: Login(TD), dtype: int64

# %% [markdown]
# In the case of huge sales customers say that Amazon.in, Flipkart.com websites take a longer time to log in. (Maybe due to very high traffic).

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="LTDG&P",data=df,palette="Dark2_r")
plt.title("Longer time in displaying graphics and photos (promotion, sales period)?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["LTDG&P"].value_counts()
# Out:
# Amazon.in, Flipkart.com                25
# Myntra.com                             14
# Amazon.in                              14
# Myntra.com, Snapdeal.com               11
# Snapdeal.com                           10
# Paytm.com                               8
# Flipkart.com, Snapdeal.com              6
# Amazon.in, Paytm.com                    6
# Amazon.in, Myntra.com, Snapdeal.com     5
# Flipkart.com                            4
# Name: LTDG&P, dtype: int64

# %% [markdown]
# Amazon.in, Flipkart.com takes a Longer time in displaying graphics and photos especially during promotion and sales periods.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Late_declaration",data=df,palette="Dark2_r")
plt.title("Late declaration of price (promotion, sales period)?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["Late_declaration"].value_counts()
# Out:
# Myntra.com                 30
# Paytm.com                  24
# Flipkart.com               14
# snapdeal.com               14
# Amazon.in                  11
# Amazon.in, Paytm.com        6
# Paytm.com, snapdeal.com     2
# Amazon.in, Flipkart.com     2
# Name: Late_declaration, dtype: int64

# %% [markdown]
# According to customer's the e-commerce websites, Myntra.com and Paytm.com have a late declaration of price during sales and promotion periods which is not good as it frustrates the customer.
#
#
# Amazon.in, Flipkart.com don't have this issue.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Page_load_time",data=df,palette="Dark2_r")
plt.title("Longer page loading time (promotion, sales period)?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["Page_load_time"].value_counts()
# Out:
# Paytm.com                           27
# Myntra.com                          22
# Flipkart.com                        11
# Amazon.in, Flipkart.com              8
# Snapdeal.com                         8
# Amazon.in, Paytm.com                 6
# Paytm.com, Snapdeal.com              5
# Flipkart.com, Snapdeal.com           5
# Amazon.in, Snapdeal.com              5
# Amazon.in                            4
# Amazon.in, Paytm.com, Myntra.com     2
# Name: Page_load_time, dtype: int64

# %% [markdown]
# Paytm.com and Myntra.com are considered as slowest in terms of loading time during sales and promotion periods.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="LTM_paymet_modes",data=df,palette="Dark2_r")
plt.title("Limited mode of payment on most products (promotion, sales period)?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["LTM_paymet_modes"].value_counts()
# Out:
# Snapdeal.com                33
# Amazon.in                   22
# Amazon.in, Flipkart.com     13
# Flipkart.com                11
# Paytm.com                   11
# Amazon.in, Paytm.com         6
# Paytm.com, Snapdeal.com      5
# Myntra.com, Snapdeal.com     2
# Name: LTM_paymet_modes, dtype: int64

# %% [markdown]
# Snapdeal.com is considered to have a Limited mode of payment on most products, especially during sales and promotion periods.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Delayed_delivery",data=df,palette="Dark2_r")
plt.title("Longer delivery period?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["Delayed_delivery"].value_counts()
# Out:
# Paytm.com                  32
# Snapdeal.com               24
# Flipkart.com               18
# Amazon.in                  11
# Paytm.com, Snapdeal.com    10
# Myntra.com                  8
# Name: Delayed_delivery, dtype: int64

# %% [markdown]
# Paytm.com and Snapdeal.com are considered to have longer delivery duration, so customers won't be satisfied with their services.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="CID",data=df,palette="Dark2_r")
plt.title("Change in website/Application design?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["CID"].value_counts()
# Out:
# Amazon.in                   38
# Paytm.com                   23
# Amazon.in, Flipkart.com     18
# Myntra.com                  13
# Flipkart.com                 7
# Snapdeal.com                 2
# Flipkart.com, Myntra.com     2
# Name: CID, dtype: int64

# %% [markdown]
# According to the customer's Amazon and Paytm websites often have UI(User interface) changes.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="FDP",data=df,palette="Dark2_r")
plt.title("Frequent disruption when moving from one page to another?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["FDP"].value_counts()
# Out:
# Myntra.com                    21
# Amazon.in                     19
# Snapdeal.com                  18
# Paytm.com                     14
# Amazon.in, Flipkart.com       11
# Flipkart.com                  10
# Flipkart.com, Snapdeal.com     5
# Myntra.com, Snapdeal.com       5
# Name: FDP, dtype: int64

# %% [markdown]
# According to some customers Myntra.com and Amazon.in have Frequent disruption when moving from one page to another

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Website_eff",data=df,palette="Dark2_r")
plt.title("Website is as efficient as before?",fontsize=15)
plt.rc('ytick',labelsize=22)
df["Website_eff"].value_counts()
# Out:
# Amazon.in                             35
# Flipkart.com                          17
# Amazon.in, Flipkart.com               15
# Amazon.in, Flipkart.com, Paytm.com    11
# Paytm.com                              8
# Amazon.in, Paytm.com                   7
# Snapdeal.com                           5
# Myntra.com, Snapdeal.com               5
# Name: Website_eff, dtype: int64

# %% [markdown]
# According to customers' Amazon.in and Flipkart.com are as efficient as before.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,12))
sns.countplot(y="Friend_Suggest",data=df,palette="Dark2_r")
plt.title("Which of the Indian online retailer would you recommend to a friend?",fontsize=15)
plt.rc("ytick",labelsize=22)
df["Friend_Suggest"].value_counts()
# Out:
# Amazon.in                                            28
# Amazon.in, Flipkart.com                              22
# Flipkart.com                                         15
# Amazon.in, Myntra.com                                14
# Amazon.in, Paytm.com, Myntra.com                      8
# Amazon.in, Paytm.com                                  6
# Amazon.in, Flipkart.com, Myntra.com                   5
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com     5
# Name: Friend_Suggest, dtype: int64

# %% [markdown]
# Amazon.in, Flipkart.com have the highest votes when making recommendations to a friend about Indian online retailers.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(y="City",data=df,palette="Dark2_r",hue="Gender")
plt.title("Which of the Indian online retailer would you recommend to a friend?",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Which of the Indian online retailer would you recommend to a friend?')

# %% [markdown]
# Overall there are more Female shoppers than males.Only Delhi and Noida has more male shoppers.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="IA",data=df,palette="Dark2_r",hue="Age")
# Out:
# <AxesSubplot:xlabel='IA', ylabel='count'>

# %% [markdown]
# A very few customers in the Age range(31 to 40) are using Dial_up service to access the internet.
#
# We can clearly observe that most people from all age ranges prefer to use mobile internet(Data pack) for online shopping.

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Device_Usage",data=df,palette="Dark2_r",hue="Age")
# Out:
# <AxesSubplot:xlabel='Device_Usage', ylabel='count'>

# %% [markdown]
# Mobile Phones and Laptops are the most used devices for online shopping especially for customers in the age range (21 to 30)

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="OS",data=df,palette="Dark2_r",hue="Age")
# Out:
# <AxesSubplot:xlabel='OS', ylabel='count'>

# %% [markdown]
# Age range (31 to 40) prefers Windows/Windows Mobile
#
# Age range (21 to 30) prefers Windows/Windows Mobile
#
# Age range (41 to 50) prefers Windows/Windows Mobile
#
# Age range (< 20) prefer Mac/Ios
#
# Age range (> 51) prefer Windows/Windows Mobile

# %%
# using Seaborn's count plot
plt.figure(figsize=(12,8))
sns.countplot(x="Browser",data=df,palette="Dark2_r",hue="Age")
# Out:
# <AxesSubplot:xlabel='Browser', ylabel='count'>

# %% [markdown]
# Google chrome is the most preferred browser among all age groups.
