# %% [markdown]
# ### Importing Selenium Libraries

# %%
#import all the required libraries

import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# ### Importing Beautiful Soup Libraries

# %%
# Importing all the libraries for beautiful soup
import requests
import bs4
import lxml

# %% [markdown]
# ### Code to display row and column border

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
# Executing the chromedriver.exe file
driver = webdriver.Chrome(r"C:\Users\charl\Desktop\Study\DataTrained\Internship\Selenium\driver\chromedriver.exe")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

# %%
driver.get(url)

# %%
click_x = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > h3 > div")

# %%
click_x.click()

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

# %%
all_cars.click()

# %%
price_filter = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

# %%
price_filter.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

# %%
under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
len(urls)
# Out:
# 118

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
print(len(Names))
print(len(Variant))
print(len(Prices))
print(len(Fuel))
print(len(Kilometers))
print(len(Purchase))
print(len(Owners))
print(len(Transmission))
print(len(Nonacc))
# Out:
# 118
# 118
# 118
# 118
# 118
# 118
# 118
# 118
# 118

# %%
# Make dataframe 
cars_df = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

# %%
cars_df["Location"] = "Delhi"

# %%
cars_df_Delhi = cars_df

# %%
cars_df_Delhi.head()
# Out:
#                                    Name           Variant    Fuel Kilometers  \
# 0       2010 Maruti Alto K10 VXI MANUAL        VXI MANUAL  Petrol  26,750 km
# 1           2008 Maruti Alto LXI MANUAL        LXI MANUAL  Petrol  22,357 km
# 2       2012 Maruti Alto 800 LXI MANUAL        LXI MANUAL  Petrol  25,610 km
# 3       2010 Maruti Alto K10 VXI MANUAL        VXI MANUAL  Petrol  40,666 km
# 4  2010 Chevrolet Beat PS PETROL MANUAL  PS PETROL MANUAL  Petrol  43,708 km
#
#     Purchase Date     Owners  Transmission     Accidential      Price Location
# 0    October 2010  2nd Owner        MANUAL  Non-Accidental  ₹1,59,299    Delhi
# 1   February 2008  1st Owner        MANUAL  Non-Accidental  ₹1,47,699    Delhi
# 2  September 2012  2nd Owner        MANUAL  Non-Accidental  ₹1,95,799    Delhi
# 3    October 2010  1st Owner        MANUAL  Non-Accidental  ₹1,89,699    Delhi
# 4               -  2nd Owner  DL-4C-x-xxxx  Non-Accidental  ₹1,28,500    Delhi

# %%
cars_df_Delhi.to_csv("cars_df_Delhi_0_2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

# %%
all_cars.click()

# %%
price_filter = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div.filter-section._1NTuv")

# %%
price_filter.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:125]

# %%
len(urls)
# Out:
# 125

# %%
urls[1]
# Out:
# 'https://www.cars24.com/buy-used-Maruti-Alto-800-2014-cars-Noida-1005820423/'

# %%
# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h1[@class='fXR9Q']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_3ueoz']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//strong[@class='_2QqSW']")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
urls[0]
# Out:
# 'https://www.cars24.com/buy-used-Maruti-Swift-2013-cars-New-Delhi-1002989646/'

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')

# %%
# Make dataframe 
cars_df_D2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

# %%
cars_df_D2["Location"] = "Delhi"

# %%
cars_df_D2.head()
# Out:
#                               Name     Variant    Fuel Kilometers  \
# 0     2013 Maruti Swift VDI MANUAL  VDI MANUAL  Diesel  11,019 km
# 1  2014 Maruti Alto 800 VXI MANUAL  VXI MANUAL  Petrol   5,383 km
# 2  2014 Maruti Alto 800 VXI MANUAL  VXI MANUAL  Petrol  12,535 km
# 3  2017 Maruti Alto 800 LXI MANUAL  LXI MANUAL  Petrol   8,501 km
# 4     2012 Maruti Swift ZXI MANUAL  ZXI MANUAL  Petrol  15,538 km
#
#     Purchase Date     Owners Transmission     Accidential      Price Location
# 0      April 2013  1st Owner       MANUAL  Non-Accidental  ₹3,78,499    Delhi
# 1  September 2014  1st Owner       MANUAL  Non-Accidental  ₹2,85,699    Delhi
# 2      March 2014  1st Owner       MANUAL  Non-Accidental  ₹2,99,499    Delhi
# 3       June 2017  1st Owner       MANUAL  Non-Accidental  ₹3,05,099    Delhi
# 4      April 2012  1st Owner       MANUAL  Non-Accidental  ₹4,53,499    Delhi

# %%
cars_df_D2.to_csv("cars_df_Delhi_D2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
price_filter = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div.filter-section._1NTuv")
price_filter.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
len(urls)
# Out:
# 140

# %%
urls = urls[:125]

# %%
len(urls)
# Out:
# 125

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_D3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

# %%
cars_df_D3["Location"] = "Delhi"

# %%
cars_df_D3.head()
# Out:
#                                                 Name  \
# 0                                                  -
# 1                  2021 Hyundai VENUE S MT 1.2 KAPPA
# 2            2020 Maruti Baleno SIGMA 1.2 K12 MANUAL
# 3          2020 Volkswagen Polo COMFORTLINE PLUS 1.0
# 4  2018 Hyundai Elite i20 Magna Executive 1.2 MANUAL
#
#                       Variant    Fuel Kilometers   Purchase Date     Owners  \
# 0                           -  Petrol     800 km    October 2020  1st Owner
# 1              S MT 1.2 KAPPA  Petrol   2,589 km      April 2021  1st Owner
# 2        SIGMA 1.2 K12 MANUAL  Petrol   4,151 km    January 2020  1st Owner
# 3        COMFORTLINE PLUS 1.0  Petrol  14,468 km   February 2020  1st Owner
# 4  Magna Executive 1.2 MANUAL  Petrol   5,937 km  September 2018  1st Owner
#
#   Transmission     Accidential      Price Location
# 0       MANUAL  Non-Accidental          -    Delhi
# 1           NA  Non-Accidental  ₹8,07,999    Delhi
# ...

# %%
cars_df_D3.to_csv("cars_df_D3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_D4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

# %%
cars_df_D4["Location"] = "Delhi"

# %%
cars_df_D4.head()
# Out:
#                                            Name  \
# 0        2020 Hyundai Creta SX PETROL MT MANUAL
# 1  2019 MG HECTOR SHARP HYBIRD PETROL MT MANUAL
# 2              2013 BMW 1 Series 116I AUTOMATIC
# 3                                             -
# 4                 2019 Hyundai VENUE SX(O) CRDi
#
#                          Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0            SX PETROL MT MANUAL  Petrol  10,671 km      June 2020  1st Owner
# 1  SHARP HYBIRD PETROL MT MANUAL  Petrol   8,528 km  November 2019  1st Owner
# 2                 116I AUTOMATIC  Petrol  21,757 km              -  2nd Owner
# 3                              -  Petrol  14,792 km   October 2019  1st Owner
# 4                     SX(O) CRDi  Diesel  25,835 km      July 2019  1st Owner
#
#    Transmission     Accidential       Price Location
# 0        MANUAL  Non-Accidental  ₹14,99,499    Delhi
# 1        MANUAL  Non-Accidental  ₹16,29,899    Delhi
# ...

# %%
cars_df_D4.to_csv("cars_df_D4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

# %%
location_select.click()

# %%
Noida = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(2) > span")

# %%
Noida.click()

# %%
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

# %%
filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_N1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_N1["Location"] = "Noida"

# %%
cars_df_N1.head()
# Out:
#                               Name          Variant    Fuel Kilometers  \
# 0   2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  26,554 km
# 1  2010 Maruti Alto K10 VXI MANUAL       VXI MANUAL  Petrol  26,750 km
# 2  2012 Maruti Alto 800 LXI MANUAL       LXI MANUAL  Petrol  25,610 km
# 3      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol  48,254 km
# 4      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol  34,611 km
#
#     Purchase Date     Owners  Transmission     Accidential      Price Location
# 0  September 2015  1st Owner        MANUAL  Non-Accidental  ₹1,23,499    Noida
# 1    October 2010  2nd Owner        MANUAL  Non-Accidental  ₹1,59,299    Noida
# 2  September 2012  2nd Owner        MANUAL  Non-Accidental  ₹1,95,799    Noida
# 3               -  1st Owner  DL-1C-x-xxxx  Non-Accidental  ₹1,50,999    Noida
# 4        May 2010  1st Owner        MANUAL  Non-Accidental  ₹1,78,499    Noida

# %%
cars_df_N1.to_csv("cars_df_N1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
Noida = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(2) > span")

Noida.click()

# %%
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:130]

# %%
len(urls)
# Out:
# 130

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_N2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_N2["Location"] = "Noida"

# %%
cars_df_N2.head()
# Out:
#                               Name     Variant    Fuel Kilometers  \
# 0     2013 Maruti Swift VDI MANUAL  VDI MANUAL  Diesel  11,019 km
# 1  2014 Maruti Alto 800 VXI MANUAL  VXI MANUAL  Petrol   5,383 km
# 2  2013 Maruti Alto 800 LXI MANUAL  LXI MANUAL  Petrol   8,967 km
# 3  2014 Maruti Alto 800 VXI MANUAL  VXI MANUAL  Petrol  12,535 km
# 4  2017 Maruti Alto 800 LXI MANUAL  LXI MANUAL  Petrol   8,501 km
#
#     Purchase Date     Owners Transmission     Accidential      Price Location
# 0      April 2013  1st Owner       MANUAL  Non-Accidental  ₹3,78,499    Noida
# 1  September 2014  1st Owner       MANUAL  Non-Accidental  ₹2,85,699    Noida
# 2   February 2013  1st Owner       MANUAL  Non-Accidental  ₹2,41,499    Noida
# 3      March 2014  1st Owner       MANUAL  Non-Accidental  ₹2,99,499    Noida
# 4       June 2017  1st Owner       MANUAL  Non-Accidental  ₹3,05,099    Noida

# %%
cars_df_N2.to_csv("cars_df_N2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
Noida = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(2) > span")

Noida.click()

# %%
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:130]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_N3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_N3["Location"] = "Noida"

# %%
cars_df_N3.head()
# Out:
#                                                 Name  \
# 0                       2020 Maruti Dzire LXI MANUAL
# 1                  2021 Hyundai VENUE S MT 1.2 KAPPA
# 2            2020 Maruti Baleno SIGMA 1.2 K12 MANUAL
# 3          2020 Volkswagen Polo COMFORTLINE PLUS 1.0
# 4  2018 Hyundai Elite i20 Magna Executive 1.2 MANUAL
#
#                       Variant    Fuel Kilometers   Purchase Date     Owners  \
# 0                  LXI MANUAL  Petrol     800 km    October 2020  1st Owner
# 1              S MT 1.2 KAPPA  Petrol   2,589 km      April 2021  1st Owner
# 2        SIGMA 1.2 K12 MANUAL  Petrol   4,151 km    January 2020  1st Owner
# 3        COMFORTLINE PLUS 1.0  Petrol  14,468 km   February 2020  1st Owner
# 4  Magna Executive 1.2 MANUAL  Petrol   5,937 km  September 2018  1st Owner
#
#   Transmission     Accidential      Price Location
# 0       MANUAL  Non-Accidental  ₹6,04,499    Noida
# 1           NA  Non-Accidental  ₹8,07,999    Noida
# ...

# %%
cars_df_N3.to_csv("cars_df_N3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
Noida = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(2) > span")

Noida.click()

# %%
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_N4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,

                           'Price':Prices})
cars_df_N4["Location"] = "Noida"

# %%
cars_df_N4.head()
# Out:
#                                            Name  \
# 0        2020 Hyundai Creta SX PETROL MT MANUAL
# 1  2019 MG HECTOR SHARP HYBIRD PETROL MT MANUAL
# 2              2013 BMW 1 Series 116I AUTOMATIC
# 3         2019 KIA SELTOS HTK 1.5 PETROL MANUAL
# 4                 2019 Hyundai VENUE SX(O) CRDi
#
#                          Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0            SX PETROL MT MANUAL  Petrol  10,671 km      June 2020  1st Owner
# 1  SHARP HYBIRD PETROL MT MANUAL  Petrol   8,528 km  November 2019  1st Owner
# 2                 116I AUTOMATIC  Petrol  21,757 km              -  2nd Owner
# 3          HTK 1.5 PETROL MANUAL  Petrol  14,792 km   October 2019  1st Owner
# 4                     SX(O) CRDi  Diesel  25,835 km      July 2019  1st Owner
#
#    Transmission     Accidential       Price Location
# 0        MANUAL  Non-Accidental  ₹14,99,499    Noida
# 1        MANUAL  Non-Accidental  ₹16,29,899    Noida
# ...

# %%
cars_df_N4.to_csv("cars_df_N4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Clicking on desired location
Gurgaon = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(3) > span")

Gurgaon.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_G1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_G1["Location"] = "Gurgaon"

# %%
cars_df_G1.head()
# Out:
#                               Name          Variant    Fuel Kilometers  \
# 0   2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  26,554 km
# 1  2010 Maruti Alto K10 VXI MANUAL       VXI MANUAL  Petrol  26,750 km
# 2  2012 Maruti Alto 800 LXI MANUAL       LXI MANUAL  Petrol  25,610 km
# 3      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol  48,254 km
# 4      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol  34,611 km
#
#     Purchase Date     Owners  Transmission     Accidential      Price Location
# 0  September 2015  1st Owner        MANUAL  Non-Accidental  ₹1,23,499  Gurgaon
# 1    October 2010  2nd Owner        MANUAL  Non-Accidental  ₹1,59,299  Gurgaon
# 2  September 2012  2nd Owner        MANUAL  Non-Accidental  ₹1,95,799  Gurgaon
# 3               -  1st Owner  DL-1C-x-xxxx  Non-Accidental  ₹1,50,999  Gurgaon
# 4        May 2010  1st Owner        MANUAL  Non-Accidental  ₹1,78,499  Gurgaon

# %%
cars_df_G1.to_csv("cars_df_G1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
Gurgaon = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(3) > span")

Gurgaon.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:125]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_G2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_G2["Location"] = "Gurgaon"

# %%
cars_df_G2.head()
# Out:
#                               Name     Variant    Fuel Kilometers  \
# 0                                -           -  Diesel  11,019 km
# 1  2014 Maruti Alto 800 VXI MANUAL  VXI MANUAL  Petrol   5,383 km
# 2  2013 Maruti Alto 800 LXI MANUAL  LXI MANUAL  Petrol   8,967 km
# 3  2014 Maruti Alto 800 VXI MANUAL  VXI MANUAL  Petrol  12,535 km
# 4  2017 Maruti Alto 800 LXI MANUAL  LXI MANUAL  Petrol   8,501 km
#
#     Purchase Date     Owners Transmission     Accidential      Price Location
# 0      April 2013  1st Owner       MANUAL  Non-Accidental          -  Gurgaon
# 1  September 2014  1st Owner       MANUAL  Non-Accidental  ₹2,85,699  Gurgaon
# 2   February 2013  1st Owner       MANUAL  Non-Accidental  ₹2,41,499  Gurgaon
# 3      March 2014  1st Owner       MANUAL  Non-Accidental  ₹2,99,499  Gurgaon
# 4       June 2017  1st Owner       MANUAL  Non-Accidental  ₹3,05,099  Gurgaon

# %%
cars_df_G2.to_csv("cars_df_G2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
Gurgaon = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(3) > span")

Gurgaon.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:125]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_G3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_G3["Location"] = "Gurgaon"

# %%
cars_df_G3.head()
# Out:
#                                                 Name  \
# 0                       2020 Maruti Dzire LXI MANUAL
# 1                                                  -
# 2            2020 Maruti Baleno SIGMA 1.2 K12 MANUAL
# 3          2020 Volkswagen Polo COMFORTLINE PLUS 1.0
# 4  2018 Hyundai Elite i20 Magna Executive 1.2 MANUAL
#
#                       Variant    Fuel Kilometers   Purchase Date     Owners  \
# 0                  LXI MANUAL  Petrol     800 km    October 2020  1st Owner
# 1                           -  Petrol   2,589 km      April 2021  1st Owner
# 2        SIGMA 1.2 K12 MANUAL  Petrol   4,151 km    January 2020  1st Owner
# 3        COMFORTLINE PLUS 1.0  Petrol  14,468 km   February 2020  1st Owner
# 4  Magna Executive 1.2 MANUAL  Petrol   5,937 km  September 2018  1st Owner
#
#   Transmission     Accidential      Price Location
# 0       MANUAL  Non-Accidental  ₹6,04,499  Gurgaon
# 1           NA  Non-Accidental          -  Gurgaon
# ...

# %%
cars_df_G3.to_csv("cars_df_G3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Gurgaon = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(3) > span")

Gurgaon.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_G4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_G4["Location"] = "Gurgaon"

# %%
cars_df_G4.head()
# Out:
#                                             Name  \
# 0   2019 MG HECTOR SHARP HYBIRD PETROL MT MANUAL
# 1               2013 BMW 1 Series 116I AUTOMATIC
# 2                  2019 Hyundai VENUE SX(O) CRDi
# 3        2019 Hyundai VENUE 1.0 TURBO GDI SX+ AT
# 4  2019 Toyota Innova Crysta 2.4 VX 7 STR MANUAL
#
#                          Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0  SHARP HYBIRD PETROL MT MANUAL  Petrol   8,528 km  November 2019  1st Owner
# 1                 116I AUTOMATIC  Petrol  21,757 km              -  2nd Owner
# 2                     SX(O) CRDi  Diesel  25,835 km      July 2019  1st Owner
# 3           1.0 TURBO GDI SX+ AT  Petrol   7,510 km      July 2019  1st Owner
# 4            2.4 VX 7 STR MANUAL  Diesel  31,235 km              -  1st Owner
#
#    Transmission     Accidential       Price Location
# 0        MANUAL  Non-Accidental  ₹16,29,899  Gurgaon
# 1  HR-51-x-xxxx  Non-Accidental  ₹12,75,000  Gurgaon
# ...

# %%
cars_df_G4.to_csv("cars_df_G4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Mumbai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(4) > span")

Mumbai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_M1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_M1["Location"] = "Mumbai"

# %%
cars_df_M1.head()
# Out:
#                                  Name            Variant    Fuel Kilometers  \
# 0  2012 Hyundai Eon MAGNA PLUS MANUAL  MAGNA PLUS MANUAL  Petrol  51,399 km
# 1      2010 Maruti Wagon R VXI MANUAL         VXI MANUAL  Petrol  49,949 km
# 2   2009 Hyundai i10 MAGNA 1.2 MANUAL   MAGNA 1.2 MANUAL  Petrol  49,357 km
# 3                                   -                  -  Petrol  16,639 km
# 4       2010 Maruti A Star VXI MANUAL         VXI MANUAL  Petrol  35,171 km
#
#     Purchase Date     Owners  Transmission     Accidential      Price Location
# 0               -  2nd Owner  MH-02-x-xxxx  Non-Accidental  ₹1,70,000   Mumbai
# 1      March 2010  1st Owner        MANUAL  Non-Accidental  ₹1,95,199   Mumbai
# 2  September 2009  2nd Owner        MANUAL  Non-Accidental  ₹1,88,699   Mumbai
# 3      March 2009  1st Owner        MANUAL  Non-Accidental          -   Mumbai
# 4   November 2010  1st Owner        MANUAL  Non-Accidental  ₹1,97,499   Mumbai

# %%
cars_df_M1.to_csv("cars_df_M1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Mumbai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(4) > span")

Mumbai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:175]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_M2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_M2["Location"] = "Mumbai"

# %%
cars_df_M2.head()
# Out:
#                                       Name                 Variant    Fuel  \
# 0       2014 Maruti Wagon R 1.0 VXI MANUAL              VXI MANUAL  Petrol
# 1       2013 Maruti Wagon R 1.0 LXI MANUAL              LXI MANUAL  Petrol
# 2  2014 Hyundai i10 MAGNA 1.1 IRDE2 MANUAL  MAGNA 1.1 IRDE2 MANUAL  Petrol
# 3       2015 Maruti Wagon R 1.0 VXI MANUAL              VXI MANUAL  Petrol
# 4          2015 Maruti Alto 800 LXI MANUAL              LXI MANUAL  Petrol
#
#   Kilometers Purchase Date     Owners Transmission     Accidential      Price  \
# 0   6,858 km     June 2014  1st Owner       MANUAL  Non-Accidental  ₹3,61,999
# 1  13,688 km      May 2013  1st Owner       MANUAL  Non-Accidental  ₹3,30,499
# 2  13,068 km     June 2014  1st Owner       MANUAL  Non-Accidental  ₹3,71,499
# 3   9,654 km    March 2015  1st Owner       MANUAL  Non-Accidental  ₹3,63,899
# 4   7,478 km     June 2015  2nd Owner       MANUAL  Non-Accidental  ₹2,66,299
#
#   Location
# 0   Mumbai
# 1   Mumbai
# ...

# %%
cars_df_M2.to_csv("cars_df_M2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Mumbai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(4) > span")

Mumbai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:130]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_M3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_M3["Location"] = "Mumbai"

# %%
cars_df_M3.head()
# Out:
#                                                 Name  \
# 0                   2018 Tata Tiago XZA 1.2 REVOTRON
# 1  2017 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT M...
# 2            2016 Maruti Baleno DELTA 1.2 K12 MANUAL
# 3               2016 Hyundai i20 Active 1.2 S MANUAL
# 4         2016 Ford Ecosport 1.5 TREND TI VCT MANUAL
#
#                         Variant    Fuel Kilometers Purchase Date     Owners  \
# 0              XZA 1.2 REVOTRON  Petrol   2,960 km  October 2018  1st Owner
# 1  SPORTZ 1.2 KAPPA VTVT MANUAL  Petrol   5,766 km    March 2017  1st Owner
# 2          DELTA 1.2 K12 MANUAL  Petrol  10,229 km    March 2016  1st Owner
# 3                  1.2 S MANUAL  Petrol  17,868 km   August 2016  2nd Owner
# 4       1.5 TREND TI VCT MANUAL  Petrol  20,644 km   August 2016  1st Owner
#
#   Transmission     Accidential      Price Location
# 0           NA  Non-Accidental  ₹5,47,699   Mumbai
# 1       MANUAL  Non-Accidental  ₹5,30,299   Mumbai
# ...

# %%
cars_df_M3.to_csv("cars_df_M3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Mumbai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(4) > span")

Mumbai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_M4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_M4["Location"] = "Mumbai"

# %%
cars_df_M4.head()
# Out:
#                                                 Name  \
# 0              2020 KIA SELTOS HTX 1.5 DIESEL MANUAL
# 1                    2020 MG HECTOR SHARP 2.0 DIESEL
# 2  2010 Mercedes Benz CLS Class 350 BLUE EFFICIEN...
# 3                    2020 KIA SELTOS GTX + AT PETROL
# 4          2020 MG HECTOR SHARP DCT PETROL AUTOMATIC
#
#                       Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0       HTX 1.5 DIESEL MANUAL  Diesel   2,765 km  February 2020  1st Owner
# 1            SHARP 2.0 DIESEL  Diesel   5,759 km      July 2020  1st Owner
# 2  350 BLUE EFFICIENCY MANUAL  Petrol  42,372 km     April 2010  3rd Owner
# 3             GTX + AT PETROL  Petrol   4,951 km              -  1st Owner
# 4  SHARP DCT PETROL AUTOMATIC  Petrol  11,480 km     March 2020  1st Owner
#
#    Transmission     Accidential       Price Location
# 0        MANUAL  Non-Accidental  ₹14,82,699   Mumbai
# 1            NA  Non-Accidental  ₹17,57,999   Mumbai
# ...

# %%
cars_df_M4.to_csv("cars_df_M4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Pune = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(5) > span")

Pune.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_P1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})
cars_df_P1["Location"] = "Pune"

# %%
cars_df_P1.head()
# Out:
#                                        Name                 Variant    Fuel  \
# 0     2011 Ford Figo 1.2 EXI DURATEC MANUAL  1.2 EXI DURATEC MANUAL  Petrol
# 1  2011 Hyundai Accent EXECUTIVE GLE MANUAL    EXECUTIVE GLE MANUAL  Petrol
# 2               2011 Maruti Alto LXI MANUAL              LXI MANUAL  Petrol
# 3           2011 Maruti Alto K10 LXI MANUAL              LXI MANUAL  Petrol
# 4           2010 Maruti Alto K10 LXI MANUAL              LXI MANUAL  Petrol
#
#   Kilometers  Purchase Date     Owners  Transmission     Accidential  \
# 0  46,292 km              -  2nd Owner  MH-43-x-xxxx  Non-Accidental
# 1  58,344 km       May 2011  1st Owner        MANUAL  Non-Accidental
# 2  48,837 km       May 2011  1st Owner        MANUAL  Non-Accidental
# 3  43,815 km      July 2011  2nd Owner        MANUAL  Non-Accidental
# 4  41,208 km  December 2010  2nd Owner        MANUAL  Non-Accidental
#
#        Price Location
# 0  ₹1,73,699     Pune
# 1  ₹1,43,899     Pune
# 2  ₹1,94,899     Pune
# ...

# %%
cars_df_P1.to_csv("cars_df_P1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Pune = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(5) > span")

Pune.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:190]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_P2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_P2["Location"] = "Pune"

# %%
cars_df_P2.head()
# Out:
#                                      Name             Variant    Fuel  \
# 0          2014 Maruti Celerio VXI MANUAL          VXI MANUAL  Petrol
# 1     2013 Hyundai i20 MAGNA O 1.2 MANUAL  MAGNA O 1.2 MANUAL  Petrol
# 2         2011 Toyota Etios Liva G MANUAL            G MANUAL  Petrol
# 3     2015 Maruti Alto K10 VXI AMT MANUAL      VXI AMT MANUAL  Petrol
# 4  2019 Maruti S PRESSO VXI AGS AUTOMATIC   VXI AGS AUTOMATIC  Petrol
#
#   Kilometers   Purchase Date     Owners  Transmission     Accidential  \
# 0  15,206 km      March 2014  1st Owner        MANUAL  Non-Accidental
# 1  13,601 km    October 2013  1st Owner        MANUAL  Non-Accidental
# 2  18,893 km               -  1st Owner  MH-01-x-xxxx  Non-Accidental
# 3   9,013 km  September 2015  1st Owner        MANUAL  Non-Accidental
# 4   1,704 km    October 2019  1st Owner     AUTOMATIC  Non-Accidental
#
#        Price Location
# 0  ₹3,62,799     Pune
# 1  ₹4,07,199     Pune
# 2  ₹2,75,299     Pune
# 3  ₹3,52,999     Pune
# ...

# %%
cars_df_P2.to_csv("cars_df_P2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Pune = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(5) > span")

Pune.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:140]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
cars_df_P3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_P3["Location"] = "Pune"

# %%
cars_df_P3.head()
# Out:
#                                                 Name  \
# 0  2015 Hyundai Grand i10 ASTA 1.2 AT VTVT AUTOMATIC
# 1                     2019 Maruti Celerio ZXI MANUAL
# 2             2018 Hyundai NEW SANTRO 1.1 SPORTS AMT
# 3            2016 Maruti Baleno DELTA 1.2 K12 MANUAL
# 4            2018 Maruti Baleno DELTA 1.2 K12 MANUAL
#
#                       Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0  ASTA 1.2 AT VTVT AUTOMATIC  Petrol  10,438 km   October 2015  1st Owner
# 1                  ZXI MANUAL  Petrol   6,499 km  February 2019  1st Owner
# 2              1.1 SPORTS AMT  Petrol   6,874 km  November 2018  1st Owner
# 3        DELTA 1.2 K12 MANUAL  Petrol   8,435 km   October 2016  1st Owner
# 4        DELTA 1.2 K12 MANUAL  Petrol   4,475 km     April 2018  1st Owner
#
#   Transmission     Accidential      Price Location
# 0    AUTOMATIC  Non-Accidental  ₹5,03,899     Pune
# 1       MANUAL  Non-Accidental  ₹5,33,499     Pune
# ...

# %%
cars_df_P3.to_csv("cars_df_P3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Pune = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(5) > span")

Pune.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_P4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_P4["Location"] = "Pune"

# %%
cars_df_P4.head()
# Out:
#                                         Name                     Variant  \
# 0  2020 MG HECTOR SHARP DCT PETROL AUTOMATIC  SHARP DCT PETROL AUTOMATIC
# 1            2020 KIA SELTOS GTX + AT PETROL             GTX + AT PETROL
# 2   2020 Hyundai VENUE SX 1.0 GDI IMT MANUAL       SX 1.0 GDI IMT MANUAL
# 3  2018 Jeep Compass 1.4 SPORT PETROL MANUAL     1.4 SPORT PETROL MANUAL
# 4  2019 MG HECTOR SHARP DCT PETROL AUTOMATIC  SHARP DCT PETROL AUTOMATIC
#
#      Fuel Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0  Petrol   5,739 km      March 2020  1st Owner    AUTOMATIC  Non-Accidental
# 1  Petrol   2,787 km    January 2020  1st Owner           NA  Non-Accidental
# 2  Petrol   3,843 km  September 2020  1st Owner       MANUAL  Non-Accidental
# 3  Petrol   6,167 km      April 2018  1st Owner       MANUAL  Non-Accidental
# 4  Petrol  28,225 km    October 2019  1st Owner    AUTOMATIC  Non-Accidental
#
#         Price Location
# 0  ₹17,71,199     Pune
# ...

# %%
cars_df_P4.to_csv("cars_df_P4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Bangaluru = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(6) > span")

Bangaluru.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_B1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_B1["Location"] = "Bangaluru"

# %%
cars_df_B1.head()
# Out:
#                              Name          Variant    Fuel Kilometers  \
# 0  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  25,514 km
# 1  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  23,494 km
# 2  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  34,394 km
# 3  2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  21,822 km
# 4  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  38,527 km
#
#     Purchase Date     Owners Transmission     Accidential      Price  \
# 0   December 2014  1st Owner       MANUAL  Non-Accidental  ₹1,81,899
# 1  September 2014  2nd Owner       MANUAL  Non-Accidental  ₹1,85,599
# 2      March 2014  1st Owner       MANUAL  Non-Accidental  ₹1,73,399
# 3    January 2015  2nd Owner       MANUAL  Non-Accidental  ₹1,91,599
# 4  September 2014  1st Owner       MANUAL  Non-Accidental  ₹1,72,599
#
#     Location
# 0  Bangaluru
# 1  Bangaluru
# 2  Bangaluru
# 3  Bangaluru
# 4  Bangaluru

# %%
cars_df_B1.to_csv("cars_df_B1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Bangaluru = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(6) > span")

Bangaluru.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:225]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_B2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_B2["Location"] = "Bangaluru"

# %%
cars_df_B2.head()
# Out:
#                                         Name                   Variant  \
# 0    2011 Hyundai Santro Xing GL PLUS MANUAL            GL PLUS MANUAL
# 1    2011 Hyundai Santro Xing GL PLUS MANUAL            GL PLUS MANUAL
# 2  2013 Hyundai i10 SPORTZ 1.2 KAPPA2 MANUAL  SPORTZ 1.2 KAPPA2 MANUAL
# 3               2015 Maruti Alto K10 VXI AMT                   VXI AMT
# 4                2012 Maruti Alto LXI MANUAL                LXI MANUAL
#
#      Fuel Kilometers Purchase Date     Owners Transmission     Accidential  \
# 0  Petrol  16,261 km     July 2011  1st Owner       MANUAL  Non-Accidental
# 1  Petrol  10,252 km     July 2011  1st Owner       MANUAL  Non-Accidental
# 2  Petrol  14,350 km  January 2013  1st Owner       MANUAL  Non-Accidental
# 3  Petrol  12,593 km     June 2015  2nd Owner           NA  Non-Accidental
# 4  Petrol  16,071 km    April 2012  2nd Owner       MANUAL  Non-Accidental
#
#        Price   Location
# 0  ₹3,21,299  Bangaluru
# 1  ₹3,03,199  Bangaluru
# ...

# %%
cars_df_B2.to_csv("cars_df_B2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Bangaluru = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(6) > span")

Bangaluru.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:130]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_B3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_B3["Location"] = "Bangaluru"

# %%
cars_df_B3.head()
# Out:
#                                             Name                 Variant  \
# 0  2020 Hyundai NEW SANTRO 1.1 SPORTS AMT MANUAL   1.1 SPORTS AMT MANUAL
# 1                 2019 Maruti Celerio VXI MANUAL              VXI MANUAL
# 2                   2014 Maruti Swift VXI MANUAL              VXI MANUAL
# 3                   2015 Maruti Swift VXI MANUAL              VXI MANUAL
# 4  2017 Hyundai Grand i10 SPORTS 1.2 VTVT MANUAL  SPORTS 1.2 VTVT MANUAL
#
#      Fuel Kilometers  Purchase Date     Owners Transmission     Accidential  \
# 0  Petrol   6,248 km  February 2020  1st Owner       MANUAL  Non-Accidental
# 1  Petrol   3,283 km    August 2019  1st Owner       MANUAL  Non-Accidental
# 2  Petrol  21,026 km  February 2014  1st Owner       MANUAL  Non-Accidental
# 3  Petrol  21,156 km      June 2015  1st Owner       MANUAL  Non-Accidental
# 4  Petrol  14,308 km      July 2017  2nd Owner       MANUAL  Non-Accidental
#
#        Price   Location
# 0  ₹6,44,399  Bangaluru
# ...

# %%
cars_df_B3.to_csv("cars_df_B3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Bangaluru = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(6) > span")

Bangaluru.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_B4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_B4["Location"] = "Bangaluru"

# %%
cars_df_B4.head()
# Out:
#                                       Name                Variant    Fuel  \
# 0       2020 MG HECTOR SMART DIESEL MANUAL    SMART DIESEL MANUAL  Diesel
# 1  2020 Jeep Compass 2.0 SPORT PLUS MANUAL  2.0 SPORT PLUS MANUAL  Diesel
# 2       2017 Mahindra XUV500 W6 4X2 MANUAL          W6 4X2 MANUAL  Diesel
# 3       2017 Mahindra XUV500 W6 4X2 MANUAL          W6 4X2 MANUAL  Diesel
# 4              2018 Mahindra XUV500 W7 FWD                 W7 FWD  Diesel
#
#   Kilometers  Purchase Date     Owners Transmission     Accidential  \
# 0   5,050 km    August 2020  1st Owner       MANUAL  Non-Accidental
# 1  31,736 km  February 2020  1st Owner       MANUAL  Non-Accidental
# 2  43,506 km      July 2017  1st Owner       MANUAL  Non-Accidental
# 3  51,159 km     March 2017  2nd Owner       MANUAL  Non-Accidental
# 4  45,553 km      July 2018  1st Owner           NA  Non-Accidental
#
#         Price   Location
# 0  ₹16,23,699  Bangaluru
# 1  ₹16,16,699  Bangaluru
# 2  ₹11,98,199  Bangaluru
# ...

# %%
cars_df_B4.to_csv("cars_df_B4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Hyderabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(7) > span")

Hyderabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_H1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_H1["Location"] = "Hyderabad"

# %%
cars_df_H1.head()
# Out:
#                                                Name                  Variant  \
# 0                       2009 Maruti Alto LXI MANUAL               LXI MANUAL
# 1                       2010 Maruti Alto LXI MANUAL               LXI MANUAL
# 2  2007 Hyundai Santro Xing XO ERLX EURO III MANUAL  XO ERLX EURO III MANUAL
# 3                       2010 Maruti Alto LXI MANUAL               LXI MANUAL
# 4                       2008 Maruti Alto LXI MANUAL               LXI MANUAL
#
#      Fuel Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0  Petrol  54,950 km       June 2009  1st Owner       MANUAL  Non-Accidental
# 1  Petrol  63,438 km   November 2010  1st Owner       MANUAL  Non-Accidental
# 2  Petrol  52,521 km  September 2007  2nd Owner       MANUAL  Non-Accidental
# 3  Petrol  59,344 km     August 2010  2nd Owner       MANUAL  Non-Accidental
# 4  Petrol  61,119 km   December 2008  1st Owner       MANUAL  Non-Accidental
#
#        Price   Location
# ...

# %%
cars_df_H1.to_csv("cars_df_H1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Hyderabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(7) > span")

Hyderabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
urls = urls[:230]

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_H2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_H2["Location"] = "Hyderabad"

# %%
cars_df_H2.head()
# Out:
#                                             Name  \
# 0  2013 Hyundai Grand i10 SPORTS 1.2 VTVT MANUAL
# 1                    2012 Maruti Alto LXI MANUAL
# 2  2017 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 3              2010 Hyundai i10 MAGNA 1.2 MANUAL
# 4             2011 Maruti Wagon R 1.0 LXI MANUAL
#
#                         Variant    Fuel Kilometers Purchase Date     Owners  \
# 0        SPORTS 1.2 VTVT MANUAL  Petrol  11,171 km  October 2013  1st Owner
# 1                    LXI MANUAL  Petrol  21,215 km     July 2012  1st Owner
# 2  5 STR WITH AC PLUSHTR MANUAL  Petrol  13,599 km    March 2017  2nd Owner
# 3              MAGNA 1.2 MANUAL  Petrol  23,488 km    March 2010  1st Owner
# 4                    LXI MANUAL  Petrol  20,979 km    March 2011  1st Owner
#
#   Transmission     Accidential      Price   Location
# 0       MANUAL  Non-Accidental  ₹4,56,599  Hyderabad
# 1       MANUAL  Non-Accidental  ₹2,54,399  Hyderabad
# ...

# %%
cars_df_H2.to_csv("cars_df_H2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Hyderabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(7) > span")

Hyderabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_H3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_H3["Location"] = "Hyderabad"

# %%
cars_df_H3.head()
# Out:
#                                                 Name  \
# 0      2017 Hyundai Grand i10 SPORTS 1.2 VTVT MANUAL
# 1      2017 Hyundai Grand i10 SPORTZ (O) 1.2 AT VTVT
# 2  2018 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT M...
# 3            2019 Maruti New Wagon-R VXI 1.2L MANUAL
# 4           2014 Maruti Swift Dzire VDI BS IV MANUAL
#
#                         Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0        SPORTS 1.2 VTVT MANUAL  Petrol  18,950 km    August 2017  2nd Owner
# 1        SPORTZ (O) 1.2 AT VTVT  Petrol  17,406 km       May 2017  1st Owner
# 2  SPORTZ 1.2 KAPPA VTVT MANUAL  Petrol  12,750 km  November 2018  2nd Owner
# 3               VXI 1.2L MANUAL  Petrol  15,186 km   January 2019  1st Owner
# 4              VDI BS IV MANUAL  Diesel  38,846 km      June 2014  2nd Owner
#
#   Transmission     Accidential      Price   Location
# 0       MANUAL  Non-Accidental  ₹5,09,599  Hyderabad
# 1           NA  Non-Accidental  ₹5,65,699  Hyderabad
# ...

# %%
cars_df_H3.to_csv("cars_df_H3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Hyderabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(7) > span")

Hyderabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_H4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_H4["Location"] = "Hyderabad"

# %%
cars_df_H4.head()
# Out:
#                                                 Name  \
# 0  2017 Toyota Innova Crysta 2.8 GX AT 7 STR AUTO...
# 1  2019 Maruti Vitara Brezza ZDI PLUS DUAL TONE M...
# 2      2019 Toyota Innova Crysta 2.4 GX 8 STR MANUAL
# 3      2018 Toyota Innova Crysta 2.4 VX 8 STR MANUAL
# 4      2017 Toyota Innova Crysta 2.4 VX 8 STR MANUAL
#
#                      Variant    Fuel   Kilometers   Purchase Date     Owners  \
# 0  2.8 GX AT 7 STR AUTOMATIC  Diesel    41,347 km   November 2017  1st Owner
# 1  ZDI PLUS DUAL TONE MANUAL  Diesel    47,337 km  September 2019  1st Owner
# 2        2.4 GX 8 STR MANUAL  Diesel  1,87,062 km      March 2019  1st Owner
# 3        2.4 VX 8 STR MANUAL  Diesel  1,81,973 km      March 2018  1st Owner
# 4        2.4 VX 8 STR MANUAL  Diesel  1,47,554 km      March 2017  1st Owner
#
#   Transmission     Accidential       Price   Location
# 0    AUTOMATIC  Non-Accidental  ₹16,33,199  Hyderabad
# 1       MANUAL  Non-Accidental  ₹11,05,099  Hyderabad
# ...

# %%
cars_df_H4.to_csv("cars_df_H4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Chennai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(8) > span")

Chennai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_CH1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_CH1["Location"] = "Chennai"

# %%
cars_df_CH1.head()
# Out:
#                                                Name                  Variant  \
# 0                       2011 Maruti Alto LXI MANUAL               LXI MANUAL
# 1                2011 Chevrolet Spark LS 1.0 MANUAL            LS 1.0 MANUAL
# 2             2008 Maruti Wagon R VXI BS III MANUAL        VXI BS III MANUAL
# 3  2007 Hyundai Santro Xing XL ERLX EURO III MANUAL  XL ERLX EURO III MANUAL
# 4       2011 Hyundai Santro Xing GL PLUS LPG MANUAL       GL PLUS LPG MANUAL
#
#            Fuel Kilometers   Purchase Date     Owners Transmission  \
# 0        Petrol  40,146 km      March 2011  1st Owner       MANUAL
# 1        Petrol  43,322 km  September 2011  1st Owner       MANUAL
# 2        Petrol  70,723 km    January 2008  1st Owner       MANUAL
# 3        Petrol  71,079 km     August 2007  1st Owner       MANUAL
# 4  Petrol + LPG  90,676 km      April 2011  2nd Owner       MANUAL
#
#       Accidential      Price Location
# 0  Non-Accidental  ₹1,93,499  Chennai
# ...

# %%
cars_df_CH1.to_csv("cars_df_CH1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Chennai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(8) > span")

Chennai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_CH2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_CH2["Location"] = "Chennai"

# %%
cars_df_CH2.head()
# Out:
#                                             Name  \
# 0                2011 Maruti Alto K10 VXI MANUAL
# 1                2013 Maruti Alto K10 VXI MANUAL
# 2                    2011 Maruti Alto LXI MANUAL
# 3             2016 Hyundai Eon MAGNA PLUS MANUAL
# 4  2018 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
#
#                         Variant    Fuel Kilometers   Purchase Date     Owners  \
# 0                    VXI MANUAL  Petrol  13,977 km      April 2011  1st Owner
# 1                    VXI MANUAL  Petrol  16,288 km  September 2013  2nd Owner
# 2                    LXI MANUAL  Petrol   9,924 km  September 2011  1st Owner
# 3             MAGNA PLUS MANUAL  Petrol   9,444 km    January 2016  2nd Owner
# 4  5 STR WITH AC PLUSHTR MANUAL  Petrol   6,145 km      March 2018  1st Owner
#
#   Transmission     Accidential      Price Location
# 0       MANUAL  Non-Accidental  ₹2,50,499  Chennai
# 1       MANUAL  Non-Accidental  ₹2,93,099  Chennai
# ...

# %%
cars_df_CH2.to_csv("cars_df_CH2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Chennai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(8) > span")

Chennai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_CH3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_CH3["Location"] = "Chennai"

# %%
cars_df_CH3.to_csv("cars_df_CH3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Chennai = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(8) > span")

Chennai.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_CH4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_CH4["Location"] = "Chennai"

# %%
cars_df_CH4.head()
# Out:
#                                    Name                Variant    Fuel  \
# 0    2019 Mahindra XUV 3OO W8(O) MANUAL           W8(O) MANUAL  Diesel
# 1  2019 Tata Hexa Varicor 400 XT MANUAL  Varicor 400 XT MANUAL  Diesel
# 2  2019 Tata Hexa Varicor 400 XT MANUAL  Varicor 400 XT MANUAL  Diesel
# 3  2017 Jeep Compass 2.0 LIMITED MANUAL     2.0 LIMITED MANUAL  Diesel
# 4       2019 KIA SELTOS GTX + AT PETROL        GTX + AT PETROL  Petrol
#
#   Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0  14,187 km     August 2019  1st Owner       MANUAL  Non-Accidental
# 1  34,262 km    January 2019  1st Owner       MANUAL  Non-Accidental
# 2  46,337 km      April 2019  1st Owner       MANUAL  Non-Accidental
# 3  24,303 km       July 2017  1st Owner       MANUAL  Non-Accidental
# 4  12,283 km  September 2019  1st Owner           NA  Non-Accidental
#
#         Price Location
# 0  ₹11,72,499  Chennai
# 1  ₹18,84,399  Chennai
# 2  ₹18,01,499  Chennai
# 3  ₹15,07,299  Chennai
# ...

# %%
cars_df_CH4.to_csv("cars_df_CH4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Kolkata = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(9) > span")

Kolkata.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_K1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_K1["Location"] = "Kolkata"

# %%
cars_df_K1.head()
# Out:
#                                    Name           Variant    Fuel Kilometers  \
# 0           2012 Maruti Alto LXI MANUAL        LXI MANUAL  Petrol  32,892 km
# 1  2013 Chevrolet Beat LS DIESEL MANUAL  LS DIESEL MANUAL  Diesel  23,885 km
#
#   Purchase Date     Owners Transmission     Accidential      Price Location
# 0  January 2012  1st Owner       MANUAL  Non-Accidental  ₹1,76,899  Kolkata
# 1  January 2013  2nd Owner       MANUAL  Non-Accidental  ₹1,46,399  Kolkata

# %%
cars_df_K1.to_csv("cars_df_K1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Kolkata = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(9) > span")

Kolkata.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_K2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_K2["Location"] = "Kolkata"

# %%
cars_df_K2.head()
# Out:
#                                        Name             Variant    Fuel  \
# 0           2018 Maruti Alto 800 LXI MANUAL          LXI MANUAL  Petrol
# 1              2012 Maruti Swift VXI MANUAL          VXI MANUAL  Petrol
# 2  2017 Hyundai Elite i20 SPORTZ 1.2 MANUAL   SPORTZ 1.2 MANUAL  Petrol
# 3       2014 Hyundai Eon D LITE PLUS MANUAL  D LITE PLUS MANUAL  Petrol
# 4              2015 Datsun Go Plus T MANUAL            T MANUAL  Petrol
#
#   Kilometers Purchase Date     Owners Transmission     Accidential      Price  \
# 0   3,697 km      May 2018  1st Owner       MANUAL  Non-Accidental  ₹3,03,499
# 1  27,056 km  January 2012  1st Owner       MANUAL  Non-Accidental  ₹3,37,699
# 2  52,065 km    April 2017  2nd Owner       MANUAL  Non-Accidental  ₹4,78,899
# 3  62,278 km  January 2014  1st Owner       MANUAL  Non-Accidental  ₹2,14,299
# 4  11,009 km      May 2015  1st Owner       MANUAL  Non-Accidental  ₹2,31,999
#
#   Location
# 0  Kolkata
# 1  Kolkata
# 2  Kolkata
# 3  Kolkata
# ...

# %%
cars_df_K2.to_csv("cars_df_K2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Kolkata = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(9) > span")

Kolkata.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Make dataframe 
cars_df_K3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_K3["Location"] = "Kolkata"

# %%
cars_df_K3.head()
# Out:
#                                        Name             Variant    Fuel  \
# 0           2018 Maruti Alto 800 LXI MANUAL          LXI MANUAL  Petrol
# 1              2012 Maruti Swift VXI MANUAL          VXI MANUAL  Petrol
# 2  2017 Hyundai Elite i20 SPORTZ 1.2 MANUAL   SPORTZ 1.2 MANUAL  Petrol
# 3       2014 Hyundai Eon D LITE PLUS MANUAL  D LITE PLUS MANUAL  Petrol
# 4              2015 Datsun Go Plus T MANUAL            T MANUAL  Petrol
#
#   Kilometers Purchase Date     Owners Transmission     Accidential      Price  \
# 0   3,697 km      May 2018  1st Owner       MANUAL  Non-Accidental  ₹3,03,499
# 1  27,056 km  January 2012  1st Owner       MANUAL  Non-Accidental  ₹3,37,699
# 2  52,065 km    April 2017  2nd Owner       MANUAL  Non-Accidental  ₹4,78,899
# 3  62,278 km  January 2014  1st Owner       MANUAL  Non-Accidental  ₹2,14,299
# 4  11,009 km      May 2015  1st Owner       MANUAL  Non-Accidental  ₹2,31,999
#
#   Location
# 0  Kolkata
# 1  Kolkata
# 2  Kolkata
# 3  Kolkata
# ...

# %%
cars_df_K3.to_csv("cars_df_K3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Kolkata = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(9) > span")

Kolkata.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_K4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_K4["Location"] = "Kolkata"

# %%
cars_df_K4.head()
# Out:
#                                    Name             Variant    Fuel  \
# 0      2018 Honda City ZX CVT AUTOMATIC    ZX CVT AUTOMATIC  Petrol
# 1  2019 Jeep Compass 2.0 LIMITED MANUAL  2.0 LIMITED MANUAL  Diesel
# 2            2014 Audi A6 35 TDI PEMIUM       35 TDI PEMIUM  Diesel
#
#   Kilometers  Purchase Date     Owners Transmission     Accidential  \
# 0  15,621 km      June 2018  1st Owner    AUTOMATIC  Non-Accidental
# 1  21,041 km  February 2019  1st Owner       MANUAL  Non-Accidental
# 2  45,325 km      June 2014  2nd Owner           NA  Non-Accidental
#
#         Price Location
# 0  ₹10,44,499  Kolkata
# 1  ₹14,79,899  Kolkata
# 2  ₹14,49,899  Kolkata

# %%
cars_df_K4.to_csv("cars_df_K4")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Ahmedabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(10) > span")

Ahmedabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='0-200000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_AM1 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_AM1["Location"] = "Ahmedabad"

# %%
cars_df_AM1.head()
# Out:
#                                  Name              Variant    Fuel Kilometers  \
# 0  2016 Tata Nano TWIST XTA AUTOMATIC  TWIST XTA AUTOMATIC  Petrol  13,430 km
# 1     2012 Maruti Alto K10 LXI MANUAL           LXI MANUAL  Petrol  83,950 km
# 2       2011 Maruti A Star VXI MANUAL           VXI MANUAL  Petrol  59,884 km
#
#   Purchase Date     Owners Transmission     Accidential      Price   Location
# 0      May 2016  1st Owner    AUTOMATIC  Non-Accidental  ₹1,70,499  Ahmedabad
# 1    March 2012  3rd Owner       MANUAL  Non-Accidental  ₹1,61,699  Ahmedabad
# 2  January 2011  1st Owner       MANUAL  Non-Accidental  ₹1,70,499  Ahmedabad

# %%
cars_df_AM1.to_csv("cars_df_AM1")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Ahmedabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(10) > span")

Ahmedabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='200000-500000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_AM2 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_AM2["Location"] = "Ahmedabad"

# %%
cars_df_AM2.head()
# Out:
#                                             Name  \
# 0  2020 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1  2020 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 2  2020 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 3  2019 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 4                    2020 Maruti Alto VXI MANUAL
#
#                         Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0  5 STR WITH AC PLUSHTR MANUAL  Petrol     749 km  November 2020  1st Owner
# 1  5 STR WITH AC PLUSHTR MANUAL  Petrol   1,999 km  February 2020  1st Owner
# 2  5 STR WITH AC PLUSHTR MANUAL  Petrol   3,822 km   January 2020  1st Owner
# 3  5 STR WITH AC PLUSHTR MANUAL  Petrol   3,540 km  November 2019  1st Owner
# 4                    VXI MANUAL  Petrol     840 km  December 2020  1st Owner
#
#   Transmission     Accidential      Price   Location
# 0       MANUAL  Non-Accidental  ₹4,85,399  Ahmedabad
# 1       MANUAL  Non-Accidental  ₹4,83,099  Ahmedabad
# ...

# %%
cars_df_AM2.to_csv("cars_df_AM2")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Ahmedabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(10) > span")

Ahmedabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='500000-1000000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
len(urls)
# Out:
# 124

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_AM3 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_AM3["Location"] = "Ahmedabad"

# %%
cars_df_AM3.head()
# Out:
#                                                 Name  \
# 0            2020 Maruti Baleno DELTA 1.2 K12 MANUAL
# 1             2020 Maruti IGNIS SIGMA 1.2 K12 MANUAL
# 2                     2020 Tata ALTROZ XT 1.2 MANUAL
# 3      2019 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 4  2017 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT M...
#
#                         Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0          DELTA 1.2 K12 MANUAL  Petrol   3,919 km      July 2020  1st Owner
# 1          SIGMA 1.2 K12 MANUAL  Petrol   3,142 km   October 2020  1st Owner
# 2                 XT 1.2 MANUAL  Petrol   1,882 km      July 2020  1st Owner
# 3  5 STR WITH AC PLUSHTR MANUAL  Petrol   7,905 km       May 2019  1st Owner
# 4  SPORTZ 1.2 KAPPA VTVT MANUAL  Petrol  19,892 km  December 2017  1st Owner
#
#   Transmission     Accidential      Price   Location
# 0       MANUAL  Non-Accidental  ₹6,63,299  Ahmedabad
# 1       MANUAL  Non-Accidental  ₹5,29,899  Ahmedabad
# ...

# %%
cars_df_AM3.to_csv("cars_df_AM3")

# %%
# URL of the cars 24 website 
url = "https://www.cars24.com/buy-used-cars/"

driver.get(url)

# %%
# Clicking on the all cars button
all_cars = driver.find_element_by_css_selector("body > div.js-content > div._3n_tN > div > div > div:nth-child(1) > div > button")

all_cars.click()

# %%
# Searching location
location_select = driver.find_element_by_css_selector("body > div.js-content > div.Ye5SB > div._1Nfgw > div > div > div.col-md-3._2VocW > p > span")

location_select.click()

# %%
# Location
Ahmedabad = driver.find_element_by_css_selector("body > div.js-content > div._3ZOW1 > div > div > div > div:nth-child(3) > ul > li:nth-child(10) > span")

Ahmedabad.click()

# %%
# Filtering Car prices
filter_price = driver.find_element_by_css_selector("body > div.js-content > div.container > div > div:nth-child(2) > ul > li:nth-child(1) > div")

filter_price.click()

# %%
under_2 = driver.find_element_by_xpath("//li[@id='1000000-9900000']")

under_2.click()

# %%
# Fetching urls
urls = []

for i in driver.find_elements_by_xpath("//div[@class='col-4']//a"):
    
    urls.append(i.get_attribute("href"))

# %%
# Name of the Car
Names = []

# Variant of the Car
Variant = []

# Price of the car
Prices = []

# Fuel_type
Fuel = []

# KMS
Kilometers = []

# Engine
Purchase = []

# Owners 
Owners = []

# Transmission
Transmission = []

# SIts
Nonacc = []



for url in urls:
    driver.get(url)
    
    # Extracting Name from xpath
    try:
        name = driver.find_element_by_xpath("//h2[@class='_2geSF']")      
        Names.append(name.text)
    except NoSuchElementException:
        Names.append('-')
    
    
    
    # Extracting variant from Css Selector
    try:
        variant = driver.find_element_by_xpath("//span[@class='_18vo2']")      
        Variant.append(variant.text)
    except NoSuchElementException:
        Variant.append('-')
        
        
     
    # Extracting Price from Css Selector
    try:
        price = driver.find_element_by_xpath("//div[@class='text-right g-hPT']//strong")      
        Prices.append(price.text)
    except NoSuchElementException:
        Prices.append('-')
        
        
    
    # Extracting fuel from Css Selector
    try:
        fuel = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(4) > strong")      
        Fuel.append(fuel.text)
    except NoSuchElementException:
        Fuel.append('-')
        
   
    # Extracting Kilometers from Css Selector
    try:
        kms = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div > div > ul > li:nth-child(3) > strong")      
        Kilometers.append(kms.text)
    except NoSuchElementException:
        Kilometers.append('-')

        
     
    # Extracting engine from Css Selector
    try:
        purchase = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(9) > strong")      
        Purchase.append(purchase.text)
    except NoSuchElementException:
        Purchase.append('-')
        
        
    
    # Extracting owner count from Css Selector
    try:
        owner = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(2) > strong")      
        Owners.append(owner.text)
    except NoSuchElementException:
        Owners.append('-')
        
     
    # Extracting Transmission from Css Selector
    try:
        trans = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(6) > strong")      
        Transmission.append(trans.text)
    except NoSuchElementException:
        Transmission.append('-')
        
     
    # Extracting seats from Css Selector
    try:
        nas = driver.find_element_by_css_selector("body > div.js-content > div._3Ii-d > div._1AvBW > div > div > div.col-8 > div > ul > li:nth-child(1) > strong")      
        Nonacc.append(nas.text)
    except NoSuchElementException:
        Nonacc.append('-')

# %%
# Make dataframe 
cars_df_AM4 = pd.DataFrame({'Name':Names,'Variant':Variant,'Fuel':Fuel,'Kilometers':Kilometers,'Purchase Date':Purchase,
                        'Owners':Owners,'Transmission':Transmission,'Accidential':Nonacc,
                        'Price':Prices})

cars_df_AM4["Location"] = "Ahmedabad"

# %%
cars_df_AM4.head()
# Out:
#                                     Name                  Variant    Fuel  \
# 0                                      -                        -       -
# 1            2019 Mahindra XUV500 W5 FWD                   W5 FWD  Diesel
# 2   2019 Jeep Compass 2.0 LIMITED MANUAL       2.0 LIMITED MANUAL  Diesel
# 3   2018 Audi A3 35TDI PREMIUM AUTOMATIC  35TDI PREMIUM AUTOMATIC  Diesel
# 4  2019 KIA SELTOS GTX 1.4 GDI AT PETROL    GTX 1.4 GDI AT PETROL  Petrol
#
#   Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0          -               -          -            -               -
# 1  28,580 km      April 2019  1st Owner           NA  Non-Accidental
# 2  60,569 km    January 2019  1st Owner       MANUAL  Non-Accidental
# 3  39,254 km   February 2018  2nd Owner    AUTOMATIC  Non-Accidental
# 4  12,143 km  September 2019  1st Owner           NA  Non-Accidental
#
#         Price   Location
# 0           -  Ahmedabad
# 1  ₹10,32,299  Ahmedabad
# 2  ₹13,14,999  Ahmedabad
# ...

# %%
cars_df_AM4.to_csv("cars_df_AM4")
