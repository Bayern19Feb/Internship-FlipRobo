# %%
import pandas as pd

# %%
df_D1 = pd.read_csv("cars_df_Delhi_0_2")
df_D2 = pd.read_csv("cars_df_Delhi_D2")
df_D3 = pd.read_csv("cars_df_D3")
df_D4 = pd.read_csv("cars_df_D4")

# %%
df_Delhi = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Delhi.head()
# Out:
#    Unnamed: 0                                  Name           Variant    Fuel  \
# 0           0       2010 Maruti Alto K10 VXI MANUAL        VXI MANUAL  Petrol
# 1           1           2008 Maruti Alto LXI MANUAL        LXI MANUAL  Petrol
# 2           2       2012 Maruti Alto 800 LXI MANUAL        LXI MANUAL  Petrol
# 3           3       2010 Maruti Alto K10 VXI MANUAL        VXI MANUAL  Petrol
# 4           4  2010 Chevrolet Beat PS PETROL MANUAL  PS PETROL MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners  Transmission     Accidential  \
# 0  26,750 km    October 2010  2nd Owner        MANUAL  Non-Accidental
# 1  22,357 km   February 2008  1st Owner        MANUAL  Non-Accidental
# 2  25,610 km  September 2012  2nd Owner        MANUAL  Non-Accidental
# 3  40,666 km    October 2010  1st Owner        MANUAL  Non-Accidental
# 4  43,708 km               -  2nd Owner  DL-4C-x-xxxx  Non-Accidental
#
#        Price Location
# 0  ₹1,59,299    Delhi
# 1  ₹1,47,699    Delhi
# ...

# %%
df_Delhi.shape
# Out:
# (483, 11)

# %%
df_Delhi.to_csv("df_Delhi")

# %%
df_D1 = pd.read_csv("cars_df_B1")
df_D2 = pd.read_csv("cars_df_B2")
df_D3 = pd.read_csv("cars_df_B3")
df_D4 = pd.read_csv("cars_df_B4")

df_Banglore = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Banglore.head()
# Out:
#    Unnamed: 0                            Name          Variant    Fuel  \
# 0           0  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 1           1  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 2           2  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 3           3  2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 4           4  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0  25,514 km   December 2014  1st Owner       MANUAL  Non-Accidental
# 1  23,494 km  September 2014  2nd Owner       MANUAL  Non-Accidental
# 2  34,394 km      March 2014  1st Owner       MANUAL  Non-Accidental
# 3  21,822 km    January 2015  2nd Owner       MANUAL  Non-Accidental
# 4  38,527 km  September 2014  1st Owner       MANUAL  Non-Accidental
#
#        Price   Location
# 0  ₹1,81,899  Bangaluru
# 1  ₹1,85,599  Bangaluru
# 2  ₹1,73,399  Bangaluru
# ...

# %%
df_Banglore.to_csv("df_Banglore")

# %%
df_D1 = pd.read_csv("cars_df_CH1")
df_D2 = pd.read_csv("cars_df_CH2")
df_D3 = pd.read_csv("cars_df_CH3")
df_D4 = pd.read_csv("cars_df_CH4")

df_Chennai = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Chennai.head()
# Out:
#    Unnamed: 0                                              Name  \
# 0           0                       2011 Maruti Alto LXI MANUAL
# 1           1                2011 Chevrolet Spark LS 1.0 MANUAL
# 2           2             2008 Maruti Wagon R VXI BS III MANUAL
# 3           3  2007 Hyundai Santro Xing XL ERLX EURO III MANUAL
# 4           4       2011 Hyundai Santro Xing GL PLUS LPG MANUAL
#
#                    Variant          Fuel Kilometers   Purchase Date  \
# 0               LXI MANUAL        Petrol  40,146 km      March 2011
# 1            LS 1.0 MANUAL        Petrol  43,322 km  September 2011
# 2        VXI BS III MANUAL        Petrol  70,723 km    January 2008
# 3  XL ERLX EURO III MANUAL        Petrol  71,079 km     August 2007
# 4       GL PLUS LPG MANUAL  Petrol + LPG  90,676 km      April 2011
#
#       Owners Transmission     Accidential      Price Location
# 0  1st Owner       MANUAL  Non-Accidental  ₹1,93,499  Chennai
# ...

# %%
df_Chennai.to_csv("df_Chennai")

# %%
df_D1 = pd.read_csv("cars_df_G1")
df_D2 = pd.read_csv("cars_df_G2")
df_D3 = pd.read_csv("cars_df_G3")
df_D4 = pd.read_csv("cars_df_G4")

df_Gurgoan = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Gurgoan.head()
# Out:
#    Unnamed: 0                             Name          Variant    Fuel  \
# 0           0   2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 1           1  2010 Maruti Alto K10 VXI MANUAL       VXI MANUAL  Petrol
# 2           2  2012 Maruti Alto 800 LXI MANUAL       LXI MANUAL  Petrol
# 3           3      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol
# 4           4      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners  Transmission     Accidential  \
# 0  26,554 km  September 2015  1st Owner        MANUAL  Non-Accidental
# 1  26,750 km    October 2010  2nd Owner        MANUAL  Non-Accidental
# 2  25,610 km  September 2012  2nd Owner        MANUAL  Non-Accidental
# 3  48,254 km               -  1st Owner  DL-1C-x-xxxx  Non-Accidental
# 4  34,611 km        May 2010  1st Owner        MANUAL  Non-Accidental
#
#        Price Location
# 0  ₹1,23,499  Gurgaon
# 1  ₹1,59,299  Gurgaon
# 2  ₹1,95,799  Gurgaon
# ...

# %%
df_Gurgoan.to_csv("df_Gurgoan")

# %%
df_D1 = pd.read_csv("cars_df_H1")
df_D2 = pd.read_csv("cars_df_H2")
df_D3 = pd.read_csv("cars_df_H3")
df_D4 = pd.read_csv("cars_df_H4")

df_Hydrabad = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Hydrabad.head()
# Out:
#    Unnamed: 0                                              Name  \
# 0           0                       2009 Maruti Alto LXI MANUAL
# 1           1                       2010 Maruti Alto LXI MANUAL
# 2           2  2007 Hyundai Santro Xing XO ERLX EURO III MANUAL
# 3           3                       2010 Maruti Alto LXI MANUAL
# 4           4                       2008 Maruti Alto LXI MANUAL
#
#                    Variant    Fuel Kilometers   Purchase Date     Owners  \
# 0               LXI MANUAL  Petrol  54,950 km       June 2009  1st Owner
# 1               LXI MANUAL  Petrol  63,438 km   November 2010  1st Owner
# 2  XO ERLX EURO III MANUAL  Petrol  52,521 km  September 2007  2nd Owner
# 3               LXI MANUAL  Petrol  59,344 km     August 2010  2nd Owner
# 4               LXI MANUAL  Petrol  61,119 km   December 2008  1st Owner
#
#   Transmission     Accidential      Price   Location
# 0       MANUAL  Non-Accidental  ₹1,77,199  Hyderabad
# ...

# %%
df_Hydrabad.to_csv("df_Hydrabad")

# %%
df_D1 = pd.read_csv("cars_df_K1")
df_D2 = pd.read_csv("cars_df_K2")
df_D3 = pd.read_csv("cars_df_K3")
df_D4 = pd.read_csv("cars_df_K4")

df_Kolkata = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Kolkata.head()
# Out:
#    Unnamed: 0                                      Name            Variant  \
# 0           0               2012 Maruti Alto LXI MANUAL         LXI MANUAL
# 1           1      2013 Chevrolet Beat LS DIESEL MANUAL   LS DIESEL MANUAL
# 0           0           2018 Maruti Alto 800 LXI MANUAL         LXI MANUAL
# 1           1              2012 Maruti Swift VXI MANUAL         VXI MANUAL
# 2           2  2017 Hyundai Elite i20 SPORTZ 1.2 MANUAL  SPORTZ 1.2 MANUAL
#
#      Fuel Kilometers Purchase Date     Owners Transmission     Accidential  \
# 0  Petrol  32,892 km  January 2012  1st Owner       MANUAL  Non-Accidental
# 1  Diesel  23,885 km  January 2013  2nd Owner       MANUAL  Non-Accidental
# 0  Petrol   3,697 km      May 2018  1st Owner       MANUAL  Non-Accidental
# 1  Petrol  27,056 km  January 2012  1st Owner       MANUAL  Non-Accidental
# 2  Petrol  52,065 km    April 2017  2nd Owner       MANUAL  Non-Accidental
#
#        Price Location
# 0  ₹1,76,899  Kolkata
# ...

# %%
df_Kolkata.to_csv("df_Kolkata")

# %%
df_D1 = pd.read_csv("cars_df_M1")
df_D2 = pd.read_csv("cars_df_M2")
df_D3 = pd.read_csv("cars_df_M3")
df_D4 = pd.read_csv("cars_df_M4")

df_Mumbai = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Mumbai.head()
# Out:
#    Unnamed: 0                                Name            Variant    Fuel  \
# 0           0  2012 Hyundai Eon MAGNA PLUS MANUAL  MAGNA PLUS MANUAL  Petrol
# 1           1      2010 Maruti Wagon R VXI MANUAL         VXI MANUAL  Petrol
# 2           2   2009 Hyundai i10 MAGNA 1.2 MANUAL   MAGNA 1.2 MANUAL  Petrol
# 3           3                                   -                  -  Petrol
# 4           4       2010 Maruti A Star VXI MANUAL         VXI MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners  Transmission     Accidential  \
# 0  51,399 km               -  2nd Owner  MH-02-x-xxxx  Non-Accidental
# 1  49,949 km      March 2010  1st Owner        MANUAL  Non-Accidental
# 2  49,357 km  September 2009  2nd Owner        MANUAL  Non-Accidental
# 3  16,639 km      March 2009  1st Owner        MANUAL  Non-Accidental
# 4  35,171 km   November 2010  1st Owner        MANUAL  Non-Accidental
#
#        Price Location
# 0  ₹1,70,000   Mumbai
# 1  ₹1,95,199   Mumbai
# ...

# %%
df_Mumbai.to_csv("df_Mumbai")

# %%
df_D1 = pd.read_csv("cars_df_N1")
df_D2 = pd.read_csv("cars_df_N2")
df_D3 = pd.read_csv("cars_df_N3")
df_D4 = pd.read_csv("cars_df_N4")

df_Noida = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Noida.head()
# Out:
#    Unnamed: 0                             Name          Variant    Fuel  \
# 0           0   2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 1           1  2010 Maruti Alto K10 VXI MANUAL       VXI MANUAL  Petrol
# 2           2  2012 Maruti Alto 800 LXI MANUAL       LXI MANUAL  Petrol
# 3           3      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol
# 4           4      2010 Maruti Alto LXI MANUAL       LXI MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners  Transmission     Accidential  \
# 0  26,554 km  September 2015  1st Owner        MANUAL  Non-Accidental
# 1  26,750 km    October 2010  2nd Owner        MANUAL  Non-Accidental
# 2  25,610 km  September 2012  2nd Owner        MANUAL  Non-Accidental
# 3  48,254 km               -  1st Owner  DL-1C-x-xxxx  Non-Accidental
# 4  34,611 km        May 2010  1st Owner        MANUAL  Non-Accidental
#
#        Price Location
# 0  ₹1,23,499    Noida
# 1  ₹1,59,299    Noida
# 2  ₹1,95,799    Noida
# ...

# %%
df_Noida.to_csv("df_Noida")

# %%
df_D1 = pd.read_csv("cars_df_P1")
df_D2 = pd.read_csv("cars_df_P2")
df_D3 = pd.read_csv("cars_df_P3")
df_D4 = pd.read_csv("cars_df_P4")

df_Pune = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Pune.head()
# Out:
#    Unnamed: 0                                      Name  \
# 0           0     2011 Ford Figo 1.2 EXI DURATEC MANUAL
# 1           1  2011 Hyundai Accent EXECUTIVE GLE MANUAL
# 2           2               2011 Maruti Alto LXI MANUAL
# 3           3           2011 Maruti Alto K10 LXI MANUAL
# 4           4           2010 Maruti Alto K10 LXI MANUAL
#
#                   Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0  1.2 EXI DURATEC MANUAL  Petrol  46,292 km              -  2nd Owner
# 1    EXECUTIVE GLE MANUAL  Petrol  58,344 km       May 2011  1st Owner
# 2              LXI MANUAL  Petrol  48,837 km       May 2011  1st Owner
# 3              LXI MANUAL  Petrol  43,815 km      July 2011  2nd Owner
# 4              LXI MANUAL  Petrol  41,208 km  December 2010  2nd Owner
#
#    Transmission     Accidential      Price Location
# 0  MH-43-x-xxxx  Non-Accidental  ₹1,73,699     Pune
# 1        MANUAL  Non-Accidental  ₹1,43,899     Pune
# ...

# %%
df_Pune.to_csv("df_Pune")

# %%
df_final = pd.concat([df_Banglore,df_Chennai,df_Delhi,df_Gurgoan,df_Hydrabad,df_Kolkata,df_Mumbai,df_Noida,df_Pune])

# %%
df_final.head()
# Out:
#    Unnamed: 0                            Name          Variant    Fuel  \
# 0           0  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 1           1  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 2           2  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 3           3  2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 4           4  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0  25,514 km   December 2014  1st Owner       MANUAL  Non-Accidental
# 1  23,494 km  September 2014  2nd Owner       MANUAL  Non-Accidental
# 2  34,394 km      March 2014  1st Owner       MANUAL  Non-Accidental
# 3  21,822 km    January 2015  2nd Owner       MANUAL  Non-Accidental
# 4  38,527 km  September 2014  1st Owner       MANUAL  Non-Accidental
#
#        Price   Location
# 0  ₹1,81,899  Bangaluru
# 1  ₹1,85,599  Bangaluru
# 2  ₹1,73,399  Bangaluru
# ...

# %%
df_final.shape
# Out:
# (3921, 11)

# %%
df_final.to_csv("df_final")

# %%
df_D1 = pd.read_csv("cars_df_AM1")
df_D2 = pd.read_csv("cars_df_AM2")
df_D3 = pd.read_csv("cars_df_AM3")
df_D4 = pd.read_csv("cars_df_AM4")

df_Ahem = pd.concat([df_D1,df_D2,df_D3,df_D4])

# %%
df_Ahem.head()
# Out:
#    Unnamed: 0                                           Name  \
# 0           0             2016 Tata Nano TWIST XTA AUTOMATIC
# 1           1                2012 Maruti Alto K10 LXI MANUAL
# 2           2                  2011 Maruti A Star VXI MANUAL
# 0           0  2020 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1           1  2020 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
#
#                         Variant    Fuel Kilometers  Purchase Date     Owners  \
# 0           TWIST XTA AUTOMATIC  Petrol  13,430 km       May 2016  1st Owner
# 1                    LXI MANUAL  Petrol  83,950 km     March 2012  3rd Owner
# 2                    VXI MANUAL  Petrol  59,884 km   January 2011  1st Owner
# 0  5 STR WITH AC PLUSHTR MANUAL  Petrol     749 km  November 2020  1st Owner
# 1  5 STR WITH AC PLUSHTR MANUAL  Petrol   1,999 km  February 2020  1st Owner
#
#   Transmission     Accidential      Price   Location
# 0    AUTOMATIC  Non-Accidental  ₹1,70,499  Ahmedabad
# ...

# %%
df_ultimate = pd.concat([df_final,df_Ahem])

# %%
df_ultimate.head()
# Out:
#    Unnamed: 0                            Name          Variant    Fuel  \
# 0           0  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 1           1  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 2           2  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 3           3  2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
# 4           4  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol
#
#   Kilometers   Purchase Date     Owners Transmission     Accidential  \
# 0  25,514 km   December 2014  1st Owner       MANUAL  Non-Accidental
# 1  23,494 km  September 2014  2nd Owner       MANUAL  Non-Accidental
# 2  34,394 km      March 2014  1st Owner       MANUAL  Non-Accidental
# 3  21,822 km    January 2015  2nd Owner       MANUAL  Non-Accidental
# 4  38,527 km  September 2014  1st Owner       MANUAL  Non-Accidental
#
#        Price   Location
# 0  ₹1,81,899  Bangaluru
# 1  ₹1,85,599  Bangaluru
# 2  ₹1,73,399  Bangaluru
# ...

# %%
df_ultimate.shape
# Out:
# (4242, 11)

# %%
df_ultimate = df_ultimate.drop("Unnamed: 0",axis=1)

# %%
df_ultimate.head()
# Out:
#                              Name          Variant    Fuel Kilometers  \
# 0  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  25,514 km
# 1  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  23,494 km
# 2  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  34,394 km
# 3  2015 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  21,822 km
# 4  2014 Tata Nano XT TWIST MANUAL  XT TWIST MANUAL  Petrol  38,527 km
#
#     Purchase Date     Owners Transmission     Accidential      Price  \
# 0   December 2014  1st Owner       MANUAL  Non-Accidental  ₹1,81,899
# 1  September 2014  2nd Owner       MANUAL  Non-Accidental  ₹1,85,599
# 2      March 2014  1st Owner       MANUAL  Non-Accidental  ₹1,73,399
# 3    January 2015  2nd Owner       MANUAL  Non-Accidental  ₹1,91,599
# 4  September 2014  1st Owner       MANUAL  Non-Accidental  ₹1,72,599
#
#     Location
# 0  Bangaluru
# 1  Bangaluru
# 2  Bangaluru
# 3  Bangaluru
# 4  Bangaluru

# %%
df_ultimate = df_ultimate.sample(frac=1).reset_index(drop=True)

# %%
df_ultimate.shape
# Out:
# (4242, 10)

# %%
df_ultimate.to_csv("df_ultimate_FINAL")
