# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
# importing BeautifulSoup
from bs4 import BeautifulSoup
import os

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r"C:\Users\charl\Desktop\Study\DataTrained\Internship\Selenium\driver\chromedriver.exe")

# %%
# URL of the website 
url = "https://www.amazon.in/"

# %%
# Fetching the url
driver.get(url)

# %%
# Input text
query_search = driver.find_element_by_css_selector("#twotabsearchtextbox")

# %%
query_search.send_keys("Sarees")

# %%
search_btn = driver.find_element_by_css_selector("#nav-search-submit-button")

# %%
search_btn.click()

# %%
# Collecting url's
urls = []

base_url = "https://www.amazon.in/s?k=Sarees&page={}&qid=1632112444&ref=sr_pg_{}"

for i in range(2,10):
    
    driver.get(base_url.format(i,i))
    
    for url in driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']"):
        
        urls.append(url.get_attribute("href"))

# %%
urls = urls[:300]

# %%
len(urls)
# Out:
# 300

# %%
urls[0]
# Out:
# 'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_next_aps_sr_pg2_1?ie=UTF8&adId=A0963485152LHHKTPJ4M6&url=%2FSATTVA-Womens-Cotton-Blouse-Black-Beige_Free%2Fdp%2FB09FZ4LNW8%2Fref%3Dsr_1_49_sspa%3Fdchild%3D1%26keywords%3DSarees%26qid%3D1632113567%26sr%3D8-49-spons%26psc%3D1&qualifier=1632113567&id=902566171156627&widgetName=sp_atf_next'

# %%
# Grabbing image source

images_sarees = []

for link in urls:
    
    driver.get(link)
    time.sleep(1)
    
    try:
        
        img = driver.find_element_by_css_selector("#landingImage")
    
        source= img.get_attribute('src')
    
        images_sarees.append(source)
        
    except NoSuchElementException:
        
        images_sarees.append("Image Not Found!")

# %%
len(images_sarees)
# Out:
# 300

# %%
import requests

# %%
for i in range(len(images_sarees)):
    
    print("Downloading....")
    
    response= requests.get(images_sarees[i])
    
    file = open(r"C:\Users\charl\Desktop\Study\DataTrained\Internship\Image Classification\Sarees"+str(i)+".jpg", "wb")
    
    file.write(response.content)
# Out:
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# ...

# %%
# URL of the website 
url = "https://www.amazon.in/"

# %%
# Fetching the url
driver.get(url)

# %%
# Input text
query_search = driver.find_element_by_css_selector("#twotabsearchtextbox")

# %%
query_search.send_keys("Trousers Men")

# %%
search_btn = driver.find_element_by_css_selector("#nav-search-submit-button")

# %%
search_btn.click()

# %%
# Collecting url's
urls = []

base_url = "https://www.amazon.in/s?k=Trousers+Men&page={}&qid=1632120589&ref=sr_pg_{}"

for i in range(2,12):
    
    driver.get(base_url.format(i,i))
    
    for url in driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']"):
        
        urls.append(url.get_attribute("href"))

# %%
# Grabbing image source

images_trousers = []

for link in urls:
    
    driver.get(link)
    time.sleep(1)
    
    try:
        
        img = driver.find_element_by_css_selector("#landingImage")
    
        source= img.get_attribute('src')
    
        images_trousers.append(source)
        
    except NoSuchElementException:
        
        images_trousers.append("Image Not Found!")

# %%
images_trousers[0]
# Out:
# 'https://m.media-amazon.com/images/I/81-9O33VgBL._UY550_.jpg'

# %%
for i in range(len(images_trousers)):
    
    print("Downloading....")
    
    response= requests.get(images_trousers[i])
    
    file = open(r"C:\Users\charl\Desktop\Study\DataTrained\Internship\Image Classification\Trousers"+str(i)+".jpg", "wb")
    
    file.write(response.content)
# Out:
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# ...

# %%
# URL of the website 
url = "https://www.amazon.in/"

# %%
# Fetching the url
driver.get(url)

# %%
# Input text
query_search = driver.find_element_by_css_selector("#twotabsearchtextbox")

# %%
query_search.send_keys("Jeans Men")

# %%
search_btn = driver.find_element_by_css_selector("#nav-search-submit-button")

# %%
search_btn.click()

# %%
# Collecting url's
urls = []

base_url = "https://www.amazon.in/s?k=Jeans+Men&page={}&qid=1632130255&ref=sr_pg_{}"

for i in range(2,16):
    
    driver.get(base_url.format(i,i))
    time.sleep(2)
    
    for url in driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']"):
        
        urls.append(url.get_attribute("href"))

# %%
len(urls)
# Out:
# 235

# %%
# Grabbing image source

images_Jeans = []

for link in urls:
    
    driver.get(link)
    time.sleep(1)
    
    try:
        
        img = driver.find_element_by_css_selector("#landingImage")
    
        source= img.get_attribute('src')
    
        images_Jeans.append(source)
        
    except NoSuchElementException:
        
        images_Jeans.append("Image Not Found!")

# %%
for i in range(len(images_Jeans)):
    
    print("Downloading....")
    
    response= requests.get(images_Jeans[i])
    
    file = open(r"C:\Users\charl\Desktop\Study\DataTrained\Internship\Image Classification\Jeans"+str(i)+".jpg", "wb")
    
    file.write(response.content)
# Out:
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# Downloading....
# ...
